# %%
# Code to find unique values in the Make column
import pandas as pd

# Load your CSV file
df = pd.read_csv('data/cleaned_aviation_data_1.csv')  # Replace with your actual file path if different

# Get unique values in the Make column
unique_makes = df['Make'].unique()

# Print the total number of unique makes
print(f"Total number of unique aircraft makes: {len(unique_makes)}")

# Print the unique values (sorted alphabetically for easier review)
print("\nUnique values in the Make column:")
for make in sorted(unique_makes):
    print(make)

# Alternative: Get value counts to see frequency of each make
print("\nTop 20 makes by frequency:")
make_counts = df['Make'].value_counts().head(20)
print(make_counts)

# Find potential inconsistencies (similar makes with different capitalization or spelling)
lowercase_makes = {}
for make in unique_makes:
    if not isinstance(make, str):
        continue
    
    lowercase = make.lower()
    if lowercase not in lowercase_makes:
        lowercase_makes[lowercase] = []
    lowercase_makes[lowercase].append(make)

# Print makes that appear with different capitalizations or spellings
print("\nPotential inconsistencies (different versions of the same make):")
for lowercase, variations in lowercase_makes.items():
    if len(variations) > 1:
        print(f"  {lowercase}: {variations}")
# Out:
# Total number of unique aircraft makes: 3395
#
# Unique values in the Make column:
# 177Mf Llc
# 2007 Savage Air Llc
# 2021Fx3 Llc
# 5 Rivers Llc
# 781569 Inc
# A. Schleicher Gmbh & Co.
# Aardema Robert John
# Ab Sportine Aviacija
# Abbett Gerry
# Abbey Victor
# Ackland Jeffrey Dean
# Acro
# Acro Sport
# Adams
# Adams Dennis Allen
# Adams Donald L
# Adams John R Jr
# Adkins
# Adolphson
# Adrian George W
# Advertising Mgmt & Consulting
# Aermacchi
# Aero Adventure
# Aero At Sp Zoo
# Aero Bristell
# Aero Commander
# Aero Smart Solutions Inc
# Aero Sp Z O O
# Aero Sp Z O O (Gobosh)
# Aero Tek Inc.
# Aero Vodochody
# Aero Vodochody Aero. Works
# Aero Works
# Aero-Ace
# Aerofab
# Aerofab Inc
# Aerofab Inc.
# Aerolite
# Aeromot
# Aeronca
# Aeronca Aircraft Corporation
# Aeroprakt
# Aeropro Cz
# Aeropro Cz S R O
# Aeros
# Aeros Ltd
# Aeros Ltd/Skyranger Aircraft
# Aerospatiale
# Aerospatiale Alenia
# Aerosport Ltd
# Aerostar
# Aerostar Acft Corp Of Texas
# Aerostar Aircraft Corporation
# Aerostar International
# Aerostar International Inc
# Aerostar S A
# Aerotechnik
# Aerotek
# Aerotek Inc
# Aerotrek
# Aerotrike
# Aerovodochody
# Ag-Cat Corporation
# Agusta
# Agusta Aerospace Corp
# Agusta Bell
# Agusta Spa
# Agustawestland Philadelphia
# Agustawestland Philadelphia Co
# Ahrens Gerd H
# Air Command
# Air Creation
# Air Creation Usa Llc
# Air Creation/Sides Rick A
# Air Gulfstream Airlines Inc
# Air Tractor
# Air Tractor Inc
# Air Tractor Inc.
# Air Tractor, Inc.
# Airborne
# Airborne (Australia)
# Airborne America
# Airborne Extreme Llc
# Airborne Windsport
# Airborne Windsports
# Airborne Windsports Pty Ltd
# Airbus
# Airbus Helicopters
# Airbus Helicopters (Eurocopte
# Airbus Helicopters Deutschland
# Airbus Helicopters Inc
# Airbus Industrie
# Airbus/Eurocopter
# Aircraft Industries A.S.
# Aircraft Mfg & Design Llc
# Aircraft Mfg & Dev. Co.
# Aircraft Mfg & Dev. Co. (Amd)
# Aircraft Mfg & Development Co
# Aircraft Mfg & Dvlpmt Co
# Airframes Unlimited
# Airgyro
# Airgyro Aviation Llc
# Airindus
# Airmax Construcoes Aeronautica
# Airplane Factory
# Airplane Factory (Pty) Ltd
# Airplane Factory (Pty) Ltd The
# Airtime
# Airtime Aircraft Inc
# Alaskan Air Adventures Llc
# Albright Stan
# Alex Michael Bantum/Tercel Usa
# Alexander
# Alexander Duane A
# Alexander Schleicher Gmbh & Co
# Alexander Thomas P
# Alexander Vagner
# Algimantas Jonusas
# Aliev Bulent
# Alisport
# Alisport Srl
# Allan G Pixley
# Allardyce Michael
# Allen
# Allen Jan A
# Allen Raymond H
# Allen Robert
# Allen W Inks
# Alliant
# Alliant Aviation
# Allstar Pzl Glider
# Alon
# Alon Aircoupe
# Alonso
# Althouse
# Alvarez Marvin R
# Amd
# Amen
# American
# American Air Racing Ltd
# American Autogyro
# American Aviation
# American Aviation Corp. (Aac)
# American Champion
# American Champion (Acac)
# American Champion Aircraft
# American Champion Aircraft Cor
# American Eurocopter
# American Eurocopter Corp
# American Eurocopter Llc
# American General Acft Corp
# American Legand Aircraft
# American Legend
# American Legend Aircraft Co
# American Legend Aircraft Co.
# American Longevity Corp
# Ames Angier M
# Amirkhanian Shahram Charl
# Ams Flight
# Ams-Flight D.O.O.
# Amstutz Curtis J
# Anatra Bart T
# Anderas
# Anderson Andreas
# Anderson Darrell L
# Anderson John H
# Anderson R E/Abromavich L J
# Andre Kostrzewa
# Andrew Harold
# Andrew Mckimmon
# Andrews
# Anglin
# Angus Watt
# Ankerstar Bradley D
# Ankestar, Bradley D.
# Antares
# Antares - Balaban
# Antares Us
# Antenor Velazco
# Anthony Mattioli
# Antonov
# Antonovich Anton B
# Apollo
# Apollo Aircraft Inc
# Appleby
# Applegate
# Arado-Flugzeugwerke Gmbh
# Arbc Inc Dba Lindstrand
# Arctic Aircraft Co Inc
# Argence
# Argence Enas A.
# Arion
# Arion Aircraft Llc
# Arion Skys Open Sport Aviation
# Ariosto James J
# Arnold
# Arnold J/Jones D L
# Arrow Falcon Exporters Inc
# Arrow Falcon Exporters, Inc.
# Arrow-Falcon Exporters, Inc.
# Art Lee Delano
# Arter Warren
# Artic Aircraft Corp.
# Arvold Jordon R
# As+ Ltd
# Ashcraft
# Aston Kinsey
# Atkins
# Atkins John
# Atkinson
# Atr
# Attaway Robert H
# Audenried
# Augustawestland
# Augustine David L
# Auman Jl
# Autogyro
# Autogyro Gmbh
# Autogyro Usa Llc
# Aveko Sro
# Aventura
# Avery Jack H
# Aves Douglas James
# Avia Stroitel
# Avian Balloon
# Aviastroitel
# Aviat
# Aviat Aircraft
# Aviat Aircraft Inc
# Aviat Aircraft Inc.
# Aviat Aircraft, Inc.
# Aviat Inc
# Aviate
# Avid
# Avid Aircraft
# Avions Fairey
# Avions Max Holste
# Avions Mudry Cie
# Avions Mudry Et Cie
# Axell Charles L
# Ayers
# Ayres
# Ayres Corp
# Ayres Corporation
# Babcock
# Babenco Henry D.
# Backovich George C
# Badeaux
# Bae
# Bae Systems
# Bagley Curtis Lynn
# Bailey
# Bailey N Moyes
# Bailey Robert
# Bailey-Moyes Microlights
# Bakeng
# Baker Bobby J
# Baker Eugene L
# Baker Victor R
# Baker Wayne
# Bal-Air Inc/Wayne John K
# Balcomb Kenneth C Iii
# Baldwin
# Ballonbau Worner Gmbh
# Balloon Works
# Balony Kubicek Spol Sro
# Barber John A
# Barber Robert L
# Barber Warren D
# Barche
# Bardouche
# Bareiss David A
# Barger Jerry L
# Barger Steve M
# Barker A E
# Barnard/Stancil
# Barnes Richard B/Howe Michael
# Barnes Steven D
# Barnes Thomas A
# Barnett Allen S
# Barney
# Barney Oldfield Aircraft Co
# Barron
# Barrow
# Barrow Ted A
# Barrows
# Barry Maggio
# Bartels
# Bartholomew
# Bartle
# Bates
# Bauer Thomas G
# Bayer Oscar
# Bayliss Milton A Iii
# Beagle
# Beam-Walter
# Bean R E/R B Weld Inc
# Bearden Biplane
# Bearhawk
# Beaudry Phillip
# Becker Elmer L
# Beckert Bruce A
# Bede
# Bedecorp Llc
# Beech
# Beech Aircraft Corp
# Beech Aircraft Corporation
# Beechcraft
# Beechcraft Corporation
# Beers
# Behne
# Belair
# Belcher
# Belcher William B Ii
# Belcher, Gerald C
# Belew Marshall D Ii
# Belisle Thomas J
# Bell
# Bell Bill
# Bell Helicopter
# Bell Helicopter Textron
# Bell Helicopter Textron Canada
# Bell Textron Canada Ltd
# Bell-Carson
# Bell-Tellijohn
# Bell-Transworld Helicopter Cor
# Bell-Transworld Helicopters
# Bell-Watson
# Bell/Garlick
# Bellanca
# Beller
# Bellet James J
# Bender
# Bender Joseph
# Benjamin Harold E
# Bennett
# Benton Fred D
# Bereznak
# Berger Bernard M
# Berger Michael A
# Beriev Aircraft Company
# Berkey
# Bernhard
# Berrie
# Berry Dean
# Bert N Norris
# Bertagna John
# Bertram William J
# Besarick
# Best Off
# Better Burn Llc/Startube Div
# Bezinque
# Bhi H60 Helicopters Llc
# Bibbee
# Bice
# Bice David E
# Bielawa
# Biesemeier David I
# Billy Amerson
# Bingham Chuck
# Binkley Richard
# Bins Tom
# Birchler Boyd
# Bird
# Biuro Projektowe B Bogumil Ber
# Bkf
# Black Christopher
# Black Donald
# Blake D Barrymore
# Blanik
# Blevens Gary
# Blondin
# Blue Oak Llc.
# Blue Side Up Inc
# Blum Matthew
# Blumer
# Boam
# Boam Larry
# Board James A
# Boatright Waylon
# Bob Frederick
# Bobbi Boucher
# Bobby Martin
# Bobo Christopher J
# Boehlke Kevin P
# Boeing
# Boeing (Stearman)
# Boeing Company
# Boeing-Stearman
# Boeing-Vertol
# Boeve Earl
# Bogle Absey C
# Bolenbaugh Phillip William
# Bolkow
# Bollinger Robert L
# Bolstridge Wallace R
# Bolton Ricky D
# Bombardier
# Bombardier Canadair
# Bombardier Inc
# Bombardier Learjet Corp.
# Bombardier, Inc.
# Bond Neal O
# Bonde
# Bordelon
# Bordelon Bruce
# Bordiuk
# Boring Robert Burton
# Borne Charles A Iii
# Borom
# Borom Marcus P
# Bosco Don
# Bosko Wr/Bosko Ce
# Boson
# Bosonetto
# Boswell John J
# Boughner
# Bowen Christopher W
# Bower
# Bowers
# Bowers Fly Baby
# Bowie Richard
# Bowles Chris
# Bowley
# Bowman
# Boyd Bruce
# Boyd Kenneth C
# Boykin Stephen Vance
# Boyle Joseph E
# Br Legend Llc
# Brad J Bates
# Bradley Roderick W
# Bradshaw
# Bradshaw / Mccauley
# Brandon Evans
# Brandt
# Brandt Leroy E
# Brantly
# Bray Verle G Jr
# Brecher Rotorway
# Breezer Aircraft
# Brenholt Larry R
# Brennan
# Brewer
# Brewer James M
# Brewster
# Brewster Fleet
# Brian P North
# Brian Turner
# Brice Ron
# Briegleb
# Brinker / Garner
# Brinkerhuff Gerald G
# Bristell
# Bristol
# British Aerospace
# British Aircraft Corp
# British Aircraft Corp.
# British Aircraft Corp. (Bac)
# Britten Norman
# Britten-Norman
# Brm Aero
# Brm Aero Sro
# Brochetti Louis
# Brock Steiner
# Brockman William A
# Brokaw Bergon F
# Brook Aaron D
# Broussard
# Brown
# Brown James W
# Brown Joseph
# Brown Joseph B Jr
# Brown Mark
# Brown Michael
# Brown Mitch
# Brown Narcisse A
# Brown Robert K
# Brown Thomas E
# Browning Gregory S
# Brubaker
# Bruce M Barrett
# Bruce R Prouse
# Bruct J Myers
# Brumbaugh B/Kasowski L
# Brumbaugh David R
# Brumwell
# Brunzlick Larry R
# Brupbacher Chris
# Bryan C L/Labrash R D
# Bryan Jerry R
# Bryan S Happell
# Bryant C Crosby
# Bryant Frederick M
# Bryk Steven L
# Buchanan
# Bucker Jungmann
# Bucker Jungmeister
# Buckeye
# Buckeye Aviation
# Buckeye Aviation Inc
# Buckeye Industries
# Buckeye Industries Inc
# Buckeye Powered Parachutes Inc
# Buckman
# Budd
# Buehlmann Peter
# Buhl
# Buhlmann Howard
# Bulfer James G
# Bumford-Royer
# Bunch
# Bunker
# Burg Frederick S
# Burkes
# Burkhart Grob
# Burkhart Grob Flugzeugbau
# Burkholder Jimmy C
# Burleigh
# Burns
# Burr
# Burrill Steven E
# Burtner Charles W
# Burton
# Burton Dennis W
# Buschmann Robert E
# Buschmann/Vanzee
# Bushby
# Bushmaster
# Butcher Russell A
# Butler Aircraft Company
# Butler John R
# Butler Raymond
# Butterhof Anthony J
# Buxbaum Mark Edward
# Byler
# Byron J. Moore
# C A S A
# C A Tecnam Srl
# C M Stuhrenberg/P C Polete
# Ca Tecnam Srl
# Calcote Clarence E
# Calvin Nate H
# Cameron
# Cameron Balloons
# Cameron Balloons Us
# Campbell
# Campbell David
# Campbell Earl S Jr
# Campbell John
# Canadair
# Canadair Ltd
# Canadian Car & Foundry
# Canadian Light Acft Sales &Svc
# Canion Michael W
# Cano Dave
# Cantlon
# Cantrell Lw
# Canup
# Capella
# Capella Aircraft Corporation (
# Capes
# Capital Holdings 226 Llc
# Capra, Salvatore O
# Carbon
# Carillon John C
# Carlesimo
# Carlo Robert
# Carlson
# Carlton M. Cadwell
# Carothers
# Carpenter
# Carr
# Carr B L
# Carr Bryan
# Carrithers Carl L
# Carter Richard L
# Cartwright H Jr/Cottrell M
# Casa
# Case Richard L
# Cashen
# Cashmer Philip M
# Casler Scott
# Cassutt
# Caughran Terry
# Ccx-2000-0081 Llc
# Celier Aviation
# Center Charles C
# Centrair
# Central Missouri State Univ
# Central Ohio Dragonfly Club
# Central Ohio Dragonfly Clubllc
# Cessna
# Cessna Aircraft
# Cessna Aircraft Co
# Cessna Aircraft Co.
# Cessna Ector
# Cessna/Air Repair Inc
# Cessna/Weaver
# Cgs
# Cgs Aviation
# Cgs Aviation Llc
# Chad Lewis
# Challenger
# Chamberlain Gerald
# Chamberlin Victor Wayne
# Champion
# Chance Vought
# Chancey Gerry M
# Chang
# Chapel Robert B
# Chapman
# Chapman Mark A
# Charland
# Charles A Brazil
# Charles C Menger Jr
# Charles D Walker
# Charles J Norris
# Charles Peet
# Charles R Kyle
# Chatham Robert M
# Chaudoin George S
# Chech Aircraft Works Spol Sro
# Cheung David S
# Chicco
# Childs Michael  A
# Chistov
# Chomo
# Chris Mitchell
# Chris W Kleen
# Christavia
# Christen Industries
# Christen Industries Inc
# Christensen Steve
# Christer
# Christiansen Don E Do
# Christopher
# Christopher John P
# Christopher Jon Brown
# Christopher Lord
# Christopher P Gage
# Christopher Tom
# Cirrus
# Cirrus Design
# Cirrus Design Corp
# Cirrus Design Corp.
# Cirrus Design Corporation
# Cismowski
# Citabria
# Clabaugh Robert R
# Clamar Floats Inc
# Clark
# Clark James T
# Clarke Colin
# Clarke Colin A
# Classic Aircraft Corp
# Claus Rodney L
# Clayhold
# Clayton Gerald H
# Clem William B Iii
# Cleveland Allan B
# Clevenger Jimmie B
# Cliff
# Clifford E Massey
# Clifton
# Clopton Aero Llc
# Cloud Jeffrey Ferrell
# Clutton Eric
# Co-Z Development Corp
# Cobalt Aircraft Industries Inc
# Cody Hawkins
# Cole Paul B
# Collard
# Collins
# Collins Robert S
# Colonial
# Colt Balloons
# Columbia
# Columbia Aircraft Mfg
# Columbia Aircraft Mfg.
# Columbia Helicopters
# Colyaer Sl
# Combs Dale B
# Combs Earl W
# Commander
# Commander Aircraft Co
# Commander Aircraft Company
# Commonwealth
# Comp Air Inc. (Plambeck)
# Concannon Milton
# Condor
# Condor Southern Powered Parach
# Cone James A
# Conner Leroy
# Conrad Theodore J
# Consolidated  Aeronautics Inc.
# Consolidated Aeronautics
# Consolidated Aeronautics Inc
# Consolidated Aeronautics Inc.
# Consolidated Aeronautics, Inc.
# Consolidated Vultee
# Construcciones Aeronauticas Sa
# Continental Copters
# Continental Copters Inc
# Continental Copters Inc.
# Convair
# Conway Philip J
# Cook
# Cooper Michael C
# Cooper, David W.
# Corbeil Shawn
# Corben Baby Ace
# Cornell W F/Sahakian J A Jr
# Cornett Steven M
# Cornford Craig H
# Corsario
# Cortesy, John E
# Corvus
# Cosentino Garey A
# Cosmos
# Cosmos Phase Ii
# Costruzioni Aeronautiche
# Costruzioni Aeronautiche Tecna
# Costruzioni Aeronautichetecnam
# Cote James
# Cotter
# Cotton Galen M
# Coulter Hugh Clarke
# Couvillion
# Covell Kevin Scott
# Covey
# Cox
# Cox Clyde H
# Cox John Wiley
# Cox William M
# Coyote
# Crabtree
# Craig A Reed
# Craig C Walls
# Craig D Carter
# Craig W Sherman
# Crain Jac A
# Crawford
# Crawford Alan R
# Creech Jerry
# Creek Michel W
# Criquet Aviation Bogota Columb
# Crisman
# Croft Robert C
# Croman
# Croman Corporation
# Crosley
# Cross David L
# Cross-Capps
# Crow
# Crowder Michael H
# Cruz
# Csp Leasing Llc
# Cub Crafter
# Cub Crafters
# Cub Crafters Inc
# Cubcrafter
# Cubcrafters
# Cubcrafters Inc
# Cubcrafters, Inc
# Cullis
# Culver
# Culver Glenn
# Cunningham
# Cupaiole
# Curnutt Elton E
# Curtis John P
# Curtis Lund
# Curtiss
# Curtiss Moses
# Curtiss Wright
# Curtiss-Wright
# Czech
# Czech Aircraft Works
# Czech Aircraft Works Spol Sro
# Czech Sport
# Czech Sport Aircraft
# Czech Sport Aircraft A S
# Czech Sport Aircraft A.S.
# Czech Sport Aircraft As
# Czech Sportplanes Sro
# D & D Aircraft
# D & K Aviation
# D-Fly
# Dacey
# Dafoe Gerald W
# Dahlman-Dower
# Dakota
# Dale Berkbigler
# Dalin Ronald K
# Dan Jelinek
# Daniel Anthony Proctor
# Daniel L Patrick
# Daniels
# Daniels Alan L
# Dankelman Peter G
# Dantonio
# Darney
# Darrell D. Dugger
# Darren M. Vinelli
# Darrow Stephen
# Darrow Stephen A
# Dart
# Daryl Baker
# Dassault
# Dassault Aviation
# Dassault Falcon
# Dassault-Breguet
# Dassault/Sud
# Davenport
# David Fitzgerald
# David Jarrett
# David L Thompson
# David S Meek
# David Shell
# David Shotwell
# David W Oakes
# Davidson
# Davidson, Ronald A.
# Davis
# Davis Benny
# Davis Dan B
# Davis Daniel T
# Davis Donald M
# Davis Frank R
# Davis John
# Davis Mark
# Davis Michael J
# Davison
# Day William L
# Dayon
# Dayton
# Dayton A Babcock
# Dayton A Dabbs
# Dayton-Wright
# De Havilland
# Dean David E
# Dean Leslie N
# Dean Patrick G
# Dearmond Clint
# Debus J / Mountain S / Bowes E
# Dedeaux Gary G
# Degraw
# Dehavilland
# Dehavilland Canada
# Deitz
# Dekkinga
# Delconte Emidio J
# Delf Tim
# Dell Lawrence
# Delwyn Schmidt
# Demmer
# Dempsey Daniel M
# Denisar Richard A
# Denney
# Dennis L Zumbalt
# Dennis P. Mcgurk
# Denny Aerocraft
# Derousse
# Desalvatore Al
# Desousa
# Destiny
# Destiny Powered Parachutes
# Destiny Powered Parachutes Llc
# Detrick Donald G
# Devoe
# Devries Wm H
# Dewsnup Dave
# Dg Flugzeugbau
# Dg Flugzeugbau Gmbh
# Dg-Flugzeugbau Gmbh
# Dial David L
# Diamond
# Diamond Aicraft Industries Inc
# Diamond Aircraft
# Diamond Aircraft Ind Gmbh
# Diamond Aircraft Ind Inc
# Diamond Aircraft Industries
# Diamond Aircraft Industry Inc
# Dickenson
# Dickey
# Dickson Vans Aircraft
# Didier Siffer (E-Ab)
# Diehl
# Diehl William A
# Dieterich Robert A
# Dietrich Ryan
# Distar Cz As
# Dittenber Thomas J
# Diven Robert
# Divis S L/Waltrip A J
# Dixon
# Dji
# Dobbs George
# Doktor Fiberglas
# Dombroski Frank
# Don W Guice
# Donald Bernard Higgs
# Donald G Stokes
# Donald K Stovall
# Donegan Benton
# Donham Timothy J
# Doppelt Fredric F
# Dormaier Monte R
# Dorman
# Dornier
# Dornier Gmbh
# Doshier Wilbert A
# Dosser Dale A
# Dotson William P
# Doubleday Donald
# Douglas
# Douglas A. Pohl
# Douglas Brian G
# Douglas D. Turner
# Douglas K Thompson
# Dova Aircraft
# Dova Aircraft Sro
# Dowell Vaughn
# Downer
# Doyle James E
# Doyle-Michael
# Dragon Fly Aviation
# Drake
# Drake Ronald A
# Dralle (Van'S Aircraft)
# Dratbe Shmiel Amir
# Dressen
# Dressen Donald L
# Dreyer
# Driggers Quillan E
# Driver
# Drochak
# Drone Paul E
# Duenas
# Dufault Mark V
# Duffy Russell A
# Duke Paul
# Dunn David
# Durfee Fred
# Durling James
# Dusenberry Mark J
# Dwight Lohr
# Dwyer Michael D
# Dykas
# Eads Socata
# Eagle
# Eagle Aircraft Co
# Eagle Aircraft Co.
# Eagle R&D Inc
# Eagleston John H
# Ealand Charles
# Earl Allen
# Earthstar Aircraft
# Easler Kelly
# Eastabrooks John T
# Easterwood Mark W
# Easton
# Eberle
# Eberle John S
# Eccker
# Eckenrode Carl J
# Eclipse
# Eclipse Aerospace Inc
# Eclipse Aviation Corp
# Eclipse Aviation Corporation
# Edson Robert W
# Edward M Van Morlan
# Edward R. Sugg
# Edward W Gray
# Edwards Douglas L
# Eggleston Daniel
# Eichhorn Gary L
# Eipper
# Eipper Formance Inc
# Eiriavion Oy
# Eldridge George
# Elemdorf
# Elkind Bruce
# Elkins
# Ellefson
# Ellumax Leasing Llc
# Elmwood
# Embraer
# Embraer Aircraft
# Embraer Executive Aircraft Inc
# Embraer S A
# Embraer S.A.
# Embraer-Empresa Brasileira De
# Emeraude
# Emerson
# Emery Mark
# Emmet Smith
# Emory B. Wood
# Enbody Frank
# Endler Glasair/Glasair 1-Td
# Engineering & Research
# Engineering And Research
# Engle David
# Enstrom
# Enstrom Helicopter Corp
# Ercoupe
# Ercoupe (Eng & Research Corp.)
# Erick Magno & Assoc Pa
# Erickson Larry D
# Eris E. Ervin
# Ernest T Christley
# Eros
# Ertz Mark G
# Ervin
# Ervin Rex H
# Eskildsen
# Eslinger C W/Eslinger S M
# Esselstyn Chuck
# Eugene Wells
# Eurocopter
# Eurocopter Deutschland
# Eurocopter Deutschland Gmbh
# Eurocopter France
# Europa
# Europro Cz
# Evans Robert W Sr
# Evektor Aerotechnik
# Evektor Aerotechnik As
# Evektor-Aerotechnik
# Evektor-Aerotechnik As
# Evens
# Evo13 Llc
# Evolution
# Evolution 19
# Evolution Air Llc
# Evolution Aircraft Inc
# Evolution Trikes
# Excalibur Aircraft
# Experimental
# Experimental Amat Built
# Explorer Aeronautique Inc.
# Express
# Extra
# Extra Flugzeugbau
# Extra Flugzeugbau Gmbh
# Extra Flugzeugproduktions-Gmbh
# Extra Flugzeugproduktions-Und
# Fagan
# Fahey William J
# Fairchild
# Fairchild Funk
# Fairchild Heli-Porter
# Fairchild Hiller
# Fairchild Swearingen
# Fairchild(Howard)
# Fairley Gooch
# Falcon Safety Craft Inc
# Falk
# Fall Martin
# Faltin John R
# Fantasy Air
# Fantasy Air Sro
# Farace Thomas Scott
# Farthing James W Ii
# Faunce
# Fdr601 Llc
# Fechtner
# Federsen Walter
# Fehlner-Shelton
# Fenton
# Feraca Edward M
# Ferdon
# Ference John W
# Ferguson Aircraft
# Ferguson William C
# Ferkin
# Fernandes Dale R
# Ferree
# Fessenden Alfred
# Fetherolf
# Fetterman Lanny R
# Fiebich Paul Dean
# Fields
# Fields Mike
# Finney Thorp
# Firefly Balloons Inc
# Fisher
# Fisher Flying Products
# Fisher Harold R
# Fisher Michael E
# Fisher Michael H
# Fk Lightplanes
# Flaglor Tom
# Fleet
# Fleetwood Jack
# Fleming Eldridge E
# Flight Design
# Flight Design General Avn Gmbh
# Flight Design Gmbh
# Flightstar
# Flightstar Inc
# Flightstar Sportplanes
# Flightworks Corp
# Flohr David J
# Flournoy Martin R
# Flower Roger P
# Floyd Joseph B
# Flugzeugproduktions-Und Vertri
# Fly Hard Trike Inc
# Flying K Enterprises
# Flynn Van
# Focke-Wulf
# Fogg
# Foglio
# Fokker
# Folland Aircraft Co Ltd
# Ford Stephen L
# Forisch Edward
# Forster
# Fortuna Dave
# Foster John
# Foster William D
# Fouga
# Found Acft Canada Inc
# Fowler
# Fox Al
# Fox Jack G
# Foxair Llc
# Foxfly Inc
# Foxworthy Rick A
# Foxworthy Roy
# Fpna
# Fpna Llc
# Frank Ware
# Franke Harry C
# Franke Roland
# Franke Russell J
# Franklin
# Frazier
# Frazier Robert L
# Frederick
# Frederick Hays-Roth
# Frederick R Goenne
# Frederickson Charles A
# Freeman
# Freeman Heritage Collection
# Frey
# Fritz
# From Here To There Pdq Inc
# Fuhrmann-Super Emeraude
# Fuji
# Fuller Neil H
# Fuller Van L
# Funk
# Funk Ralph
# Furgason James E
# Furlong
# Furru Donald Jeffrey
# G Elwin Halvorsen
# G-Dawg Llc
# Gadbois Eugene W
# Gaddis Michael
# Gage
# Gallager John C
# Gallagher
# Galloway/Ward
# Ganjoo Amit
# Garcia Benigno
# Gardner Douglas P
# Garland
# Garlick
# Garlick Helicopters Inc
# Garramone Mike A
# Garratt Mansfield W
# Garrett
# Garrett Gerald P
# Garrison Ronald L
# Gary A Jamieson
# Gary James Lail
# Gary W Bettis
# Garza
# Gaskins
# Gaston Thomas D
# Gates Lear Jet
# Gates Lear Jet Corp.
# Gates Learjet Corp.
# Gates Learjet Corporation
# Gauchat
# Gaynor Donald J
# Gearn Geary D
# Gefa-Flug Gmbh
# Geist Donald R
# Geldermann Bert E
# General Atomics
# Gentry John K
# George A. Thiel
# George Matthew Wagoner
# George W. Felix
# Gerald Dan Coppock
# Gerald Donovan
# Gerald Jones
# Gerald Nelson
# Gerdts Mark E
# Gerner
# Getten Marvin T
# Giackino Donald W
# Gibb
# Gibbs
# Giboney
# Gibson Mark
# Gier Travis H
# Giger Frank R
# Gilbert Thomas Jeffrey
# Gilchrist
# Gill Craig
# Gingerich Alton & Slagel Dean
# Gingras Michel
# Giorgio Anthony J
# Gippsaero Pty Ltd
# Gippsland
# Gladstone
# Glaeser
# Glasair
# Glasair Aviation Llc
# Glasair Aviation Usa Llc
# Glaser Dirks
# Glaser-Dirks
# Glaser-Dirks Flugzeugbau
# Glasflugel
# Glass Roy L
# Glassair
# Glenn H Curtiss Museum
# Glenn Timothy C
# Glimn
# Glines
# Glines Kenneth
# Globe
# Glos Wallis Richard Jr
# Gmk Ventures Llc
# Gn-1 Aircamper
# Goddard Dick Sim
# Godwin Jeff E
# Goetz
# Golden Circle
# Golden Circle Air
# Golden Circle Air Inc
# Golden Eagle
# Gonzalez Manuel A
# Goodacre
# Goodman Robert Bruce
# Goodsell Lynn A
# Goodyear
# Gordon
# Gordon Scot A
# Gossard Ronald F
# Gosselin Charles
# Gottelt Herbert R
# Gottschalk John R
# Goudie
# Graff Wilbur C
# Grahn J/Grahn G
# Granger Michael D
# Graves
# Graves Bryon S
# Gray
# Gray Jim Robert
# Grazhopper
# Great Lakes
# Greco
# Green Gary E
# Greene R/Greene S
# Greg Connell
# Greg Hobbs
# Greg Miller
# Gregg Origer
# Gregory Newman
# Gregory S Miller
# Gremminger Greg
# Grenier Raymond
# Griff
# Griffith E/Boyd W E
# Griffiths James Sydney
# Grimes Barry R
# Grimm
# Grob
# Grob Aircraft Ag
# Grob-Werke
# Groen
# Groom
# Grosch
# Gross
# Gross Michael E
# Grumman
# Grumman Acft Eng
# Grumman Acft Eng Cor
# Grumman Acft Eng Cor-Schweizer
# Grumman Aircraft
# Grumman Aircraft Cor-Schweizer
# Grumman Aircraft Eng Corp
# Grumman American
# Grumman American Aviation
# Grumman American Aviation Corp
# Grumman American Avn. Corp
# Grumman American Avn. Corp.
# Grumman Schweizer
# Grumman-Schweizer
# Gt Ultralights
# Guarino
# Guimbal
# Guisinger Gary G
# Gulfstream
# Gulfstream Aerospace
# Gulfstream Aerospace Corp
# Gulfstream Aerospace Corp.
# Gulfstream Am Corp Comm Div
# Gulfstream American Corp
# Gulfstream American Corp.
# Gulfstream Schweizer A/C Corp
# Gulfstream-Schweizer
# Gulfstream-Schweizer A/C Corp
# Gunnoe
# Gutierrez Pablino
# Hachem Zachery S
# Haddow William H
# Haecker
# Haeussler Ray
# Hager Clinton Ray
# Hagerty
# Haggenmacher
# Hahn
# Haines
# Haines Joseph E
# Halbert James H
# Halbrook
# Halderman, Floyd G.
# Haley
# Hall
# Hall Don H
# Hall Jeffrey
# Hall Steven C
# Hall Terrence / Hall Cathie
# Hall Thomas K
# Hall, Wendall W
# Halladay Roy
# Hallbauer
# Hallendorf Tom
# Halley Kft
# Hamlin John D
# Hammond
# Handy James L
# Haney John F B
# Hansen
# Hansen David Daniel
# Hansen Ib C
# Hanson
# Hanson Lonn
# Hanson Robert H
# Haphey Bruce Frederic
# Harden
# Hardie James D
# Hardy
# Hargett
# Hargrove
# Haring Clay
# Harms Robert M
# Harris Pierce
# Harris-Runyan
# Harrity William V
# Harrop Blake
# Harry Crosby (Vans)
# Harry L. Weber
# Harry Oas
# Hartline J Bon
# Hartter Lenny J
# Hartz Paul
# Harvey J Brock
# Harvey Patten
# Hastings Thomas G
# Hatcher Roderick R
# Hatle
# Hatz
# Hauser U/Hauser J
# Hawker
# Hawker Aircraft Ltd
# Hawker Beech
# Hawker Beechcraft
# Hawker Beechcraft Corp
# Hawker Beechcraft Corp.
# Hawker Beechcraft Corporation
# Hawker Siddeley
# Hawker-Beechcraft
# Hawker-Beechcraft Corporation
# Hawkins August E
# Hawley Richard
# Haycraft
# Hazelwood Michael S
# Head
# Head Balloons Inc
# Head Balloons Inc.
# Head Balloons, Inc.
# Healy
# Heard Alan E
# Heberlein Ronald
# Hebert
# Hebert Peter J
# Heckel
# Hefty
# Hein
# Heinlein George
# Heinz
# Heiser Robert C Jr
# Heisler
# Heldeberg Design
# Helicopteres Guimbal
# Helicycle/Morrisey Rr
# Helie
# Helio
# Helpling Helen C
# Helton
# Hemmer
# Hemp Timothy
# Hencken William
# Henderson
# Henderson Clifford S
# Henderson Michael E
# Henderson W A/Johnson W L
# Hendricks George David Jr
# Hendryx Steve/Wiley Ross
# Henney Michael A
# Henrie Raymond
# Henry L Berrier Jr
# Henry Slosing
# Henry Steven J
# Herder Michael
# Herem
# Herink H R/Herink R W
# Hermann Bjorn
# Heronimus Kevin A
# Herzog Aviation
# Hess John L
# Hi-Max
# Hibbard Norman E
# Hickham
# Hickox Andy
# Hier James A
# Higgins John H/Williams John D
# Higher Class Aviation
# Hilderson Oswald
# Hill
# Hill Group Llc
# Hillam Scott L
# Hillard Charlie R
# Hiller
# Hiller-Rogerson Helicopter
# Hiller-Tri-Plex Ind.Inc.
# Himmeroeder Hansgeorg
# Himsl Vincent S
# Hinton Paul M
# Hirn Associates Ltd
# Hisserich Nicholas S
# Hitchcock
# Hoac-Austria
# Hodges Samuel J
# Hoffius Stowe
# Hoffman
# Hoffman David J
# Hoffman David K
# Hoffmann
# Hogan
# Hoke Bobby F
# Holden Frank Joseph
# Holland
# Holland Mike
# Holley Carol L
# Hollier B C
# Holloman L B/Holloman E M
# Holm Michael J
# Holmes Arthur Orman
# Holmes Gary Don
# Holmes William E
# Holmgreen John B
# Holmgren
# Holmlund Victor P
# Holsclaw Francis E
# Holst Lawrence E
# Holt Herbert L
# Homer
# Honda Aircraft
# Honda Aircraft Co Llc
# Honda Jet
# Hood
# Hood John Sidney
# Hook
# Hooper James A
# Hoover David
# Hoover Frank
# Hoskins
# Hoskins Lonnie F
# Hoskins Samuel R
# Hostein K/Hostein S
# Houts
# Howard
# Howard Aircraft
# Howard M. Shepherd
# Howard Steven C
# Howard William C
# Howell
# Howell Bob
# Howes
# Hoyle
# Hph Ltd
# Hph Spol Sro
# Hph, Spol. S.R.O.
# Hrosik Gene
# Hubbard William H
# Hubbell
# Huber Hartmut
# Hudson
# Huebbe
# Huebner
# Hughes
# Hughes Aero
# Hughes Aero Corp
# Hughes Charles R
# Hughes Helicopters Inc
# Hughes J/Hughes J
# Hughes/Helicopter Assocs Inc
# Hummel / Finberg
# Hummelbird
# Hummer
# Hundley Michael J
# Hunt
# Hunter
# Hunter George
# Hunthrop
# Hunziker
# Hurley Richard A
# Huston Charles D
# Hutchinson Kenneth A
# Hutson
# Hutton
# Hy-Tek
# Hyde William R
# I.C.A.-Brasov
# I.C.A.-Brasov (Romania)
# Iai
# Iar Brasov
# Ica Brasov
# Icon
# Icon Aircraft Inc
# Icp
# Ilyushin
# Independent Technologies Inc
# Indus
# Indus Aviation Inc
# Indus Aviation Inc.
# Indy Aircraft Ltd
# Infinity
# Infinity Power Parachutes
# Infinity Power Parachutes Llc
# Ingraham
# Inhofe/ Davis
# Iniziative Industriali Italian
# Inman J D
# Innovator
# Innovator Technologies
# Interplane
# Interplane S R O
# Interstate
# Irlbeck Thomas H
# Irvin Stephen D
# Isaak Paul G
# Ison Aircraft
# Israel Aerospace Industriesltd
# Israel Aircraft Industries
# Issitt
# Issoire Siren
# Itec Inc
# Iversen
# J&J Ultralights
# J. E. Douglas
# J. Schilling
# Jabiru
# Jabiru Aircraft Pty Ltd
# Jabiru Usa Sport Aircraft
# Jabiru Usa Sport Aircraft Llc
# Jabiru Usa Sport Aircraft, Llc
# Jack A Frohbieter
# Jack Fehling
# Jackson
# Jackson Dennis
# Jackson Fred M
# Jackson Jeremiah D
# Jacobs
# Jacquneaux Glen R
# Jahns
# Jal R Dennis
# James
# James A Gray
# James B. Taplin
# James Bruton
# James C Geyman
# James D Riggs
# James Dayton
# James Donald Baker
# James E Causey
# James F Hake
# James H Berard
# James Kilroy
# James M Raulerson
# James O'Bert
# James Wiebe
# Jannakos Gregory P
# Jans Robert
# Jansen
# Jantzen
# Javron
# Javron Experimental
# Jdt
# Jdt Mini-Max Llc
# Jeff Jardine
# Jeffair
# Jeffery D Tuttle
# Jeffko
# Jenkins
# Jenkins Jack
# Jennings John C
# Jeremiah Jackson
# Jerome A Baak
# Jerome D Fischer
# Jess Llc
# Jesse Saint/Troy Townsend/Etha
# Jetprop Dlx Piper
# Jetson'S Aviation Llc
# Jewett
# Jewett Brandon
# Jihlavan
# Jihlavan Airplanes Sro
# Jim Braddock
# Jim Green
# Jim Riggs
# Jimenez
# Joe Salomone
# Joel A Bowker
# John A Brewer
# John Goodman
# John M Corneal
# John Murphy
# John Roscoe
# John Sample
# John Steven Caturia
# John V Rawson Jr
# Johnny F Anderson
# Johnson
# Johnson Barron T
# Johnson David Earl
# Johnson Garret W
# Johnson Gary
# Johnson Gerald
# Johnson Glenn L
# Johnson Jerry
# Johnson Joel H
# Johnson Kenneth
# Johnson Kenneth R
# Johnson Kenneth W
# Johnson Leonard G
# Johnston Coyt E
# Johnston Douglas S
# Johnston William Alfred Jr
# Jones
# Jones Kent C
# Jones Peter M
# Jones Ralph D
# Jones Rodney V
# Jones Ronald C
# Jonker
# Jonker Sailplanes
# Jonker Sailplanes (Pty) Ltd
# Jonker Sailplanes Cc
# Jonsson
# Jordan Bruce C
# Jordan Don R
# Jordan John
# Jordan Valley Llc
# Jorritsma Jerrold S
# Joseph Bender
# Joseph C. Andrews, Jr.
# Joy Aviation Ltd
# Judd
# Jude Mike C
# Juneau (Zenith Aircraft Co)
# Jurcan
# Jurmu
# Just
# Just Aircraft
# Just Aircraft Llc
# Justice Frank K
# Juve Richard G
# K Copters
# Kade
# Kai Engstad
# Kakeldey Ronald O
# Kaldor Gregory N
# Kalman George
# Kaman
# Kaman Aerospace Corp
# Kaminskas
# Kamtz
# Kamtz Russell H
# Karibian Hurant
# Karns
# Karpayev Vladyslav V
# Kaufmann
# Kaylor J E/Strahlmann R L
# Keeley/Tidd
# Keesler
# Keithley Thomas E
# Keller
# Kelley Derrick/Leza
# Kelly
# Kelm David
# Ken Olson
# Kendall W R/Mclaughlin J
# Kennedy
# Kennedy Michael M
# Kenneth A Berger
# Kenneth B Hines
# Kenneth K Knowles
# Kenneth M Franz
# Kenney
# Kermit Weeks
# Kerns Kenneth H
# Kerr Gerald
# Kerr John A
# Kerr Matthew
# Kessinger Roger L
# Ketonen
# Keuthan
# Keuthan Aircraft Corp
# Kevin Eldredge
# Kevin Leue
# Kevin Lippert
# Kevin Metzler
# Kevin Wilkinson
# Kidd Chris
# Kilishek George T
# Killgore
# Kimball Enterprises Inc
# Kincaid Wade
# Kindig
# King John E Jr
# Kinner
# Kinney Kevin
# Kinsler Arthur Paul
# Kirbybilt Aircraft
# Kirk Ellis Wendell
# Kirkpatrick
# Kitfox
# Kitfox Iv
# Kitty Hawk
# Kjonaas
# Kjostad Jorgen A
# Klaas Development Inc
# Klemme William H
# Klemp Gregory J
# Knapp
# Knauf
# Knell
# Knight
# Knott Vernon W
# Knox Marion L
# Kociemba Robert H
# Koen Lancair
# Kolb
# Kolb Aircraft Co
# Kolb Aircraft Inc
# Koleno
# Koons Donald H
# Korrison Tom
# Kostrazewa Andre
# Koth Larry
# Kovars Gary D
# Kral
# Kramer Clemens E
# Kreling
# Kreps
# Kretsinger
# Krips Jack E Jr
# Krusmark David Homer
# Kubassek David
# Kubicek
# Kumhyr David B
# Kundel
# Kuntz
# Kurtz Jay B
# Kuykendall Charles
# Kwech
# Kyle M Sward / Larry W Sward
# L Goldner
# L-Bird Llc
# La Moutte
# Lacour
# Laird
# Lake
# Lake John K
# Lamb-Robin
# Laminar
# Lammers Sjef J
# Lancair
# Lancair Company
# Lance M Hooley
# Landrum Kelly T
# Lange Flugzeugbau Gmbh
# Langston, Frederick L
# Lanham
# Lanier James A
# Lankenau
# Lansdorf
# Lanshe Aerospace
# Lantz
# Lantzair Flyers Inc
# Larry H Sligar
# Larry Ketterling
# Larsen
# Larson
# Larson Ken W
# Larson Roger H
# Laseure
# Lathrop Steven A
# Laurienzo Gabriel A
# Lauritsen Ralph M
# Lavender Alan P
# Lavigna
# Lawrence O Nolte
# Lawson J/Bowie R/Smith M
# Lawson Ron
# Lawson Ronald S
# Lawwill Ted
# Layson Stanley B
# Lazair
# Lazear John T
# Leach Michael
# League
# Learjet
# Learjet Inc
# Leatherman Karl L
# Leder John A
# Lee Oscar D Iii
# Lee Paul
# Lefever Paul M
# Leider
# Leigh
# Leineke Walter L
# Lemond
# Lennox Kenneth J
# Leon E Everett
# Leonard Trudy
# Leonardo
# Lepow David A
# Lerch
# Leroux John F
# Leroy Lakey
# Lester Robert E
# Let
# Levy Adam V
# Lewis Brandon Scott
# Lewis Jennings
# Lewis Keith O
# Leza Lockwood
# Liberty Aerospace Inc.
# Liberty Aerospace Incorporated
# Lien
# Lightning Avion Eab Llc
# Lima
# Liming Louis L
# Lindstrand
# Lindstrand Balloons
# Linke
# Linstrand
# Lite Flight
# Liteflite Pty Ltd
# Lithuanian Factory Of Aviation
# Llewellyn, Warwinc W
# Lobb Kenneth
# Lockheed
# Lockwood
# Lockwood Aircraft Corp
# Loehle Aircraft Corp
# Loehr Thomas H
# Loflin
# Logan Jerry L
# Long
# Loofbourrow John W
# Loomis
# Lopez Phillip
# Lorah Elden A
# Lorentzen
# Lorenz Stephen
# Lowerre Bruce T
# Lsa America Inc
# Lucas D E/ Lucas K A
# Luciano Edison
# Ludwig Larry E
# Lueck
# Lunceford
# Lundak Robert
# Luscombe
# Luscombe Silvaire Aircraft Co.
# Luttenbacher Kurt
# Luy Wayman
# Lydon Patrick F
# Lyman Randall/Scott David
# Lynn Perry
# Lyons
# Lyons Robert
# M Squared
# M-Squared
# M-Squared Aircraft
# Maarten H Versteeg
# Macadams
# Macdonald Craig
# Mace Justin I
# Macleod
# Madera
# Maggs
# Magnaghi Aeronautica Spa
# Magni
# Magnus Aircraft Llc
# Maher Daniel J
# Mahon Paul D
# Mahre
# Main Air
# Makela
# Malinowski Walter S
# Malkin Roy K
# Mallory Christopher L
# Malone Henry O
# Maniscalco
# Mantell Allan T
# Mantooth
# Manweiller
# Manzitto Michael A
# Marconi Fred I Jr
# Marino
# Mark C Pauls
# Mark Coby
# Mark Divita
# Mark Goldberg
# Marks Ca Iii
# Marks Steven
# Marley
# Marlin
# Marlman
# Marlow
# Marrero Andres
# Marrin
# Marsh Aviation
# Marshall
# Marshall James J
# Martin Charles A
# Martin Curtis
# Martin Edward H
# Marvin A. Smith
# Marvin Faulk
# Mas Events
# Mason
# Mason Hal J
# Mason Robert
# Mateskon
# Matheny Larry E
# Mathias Linda B
# Mathieu
# Mathis Melvin R
# Matthews H Thomas
# Mauck
# Maule
# Maurer Elmo A
# Max A Boesiger Jr
# Maxair
# Maxair Drifter
# Maxcy Christopher L
# Maxfly Inc/Mckay Wm
# Mayo
# Mays
# Mazurek Keith P
# Mbb
# Mcadam W E
# Mcarthur
# Mccauley Gene E
# Mccleery
# Mcclish
# Mcclure B J
# Mccluskey
# Mccorkle Robert B
# Mccowan Steve A
# Mccrary Bobby C Jr
# Mcculley Ronald
# Mcculloch Jerry
# Mccurdy
# Mccurry Charles P
# Mcdaniel
# Mcdaniel James D
# Mcdonald Howard Brian
# Mcdonald Lynn B
# Mcdonnell Douglas
# Mcdonnell Douglas Aircraft Co
# Mcdonnell Douglas Corporation
# Mcdonnell Douglas Heli Co
# Mcdonnell Douglas Helicopter
# Mcdonnell Douglas Helicopter C
# Mcdonnell Douglas Helicopters
# Mcfarland Bill
# Mcfarland Wm H
# Mcglashan
# Mcgrath Robert F
# Mcguire
# Mchargue
# Mchenry George B Jr
# Mcholland
# Mcholland C L
# Mchugh Tony
# Mcintosh Donald W
# Mckay Gene
# Mckeehan James F
# Mckenna
# Mckenna James E
# Mckenzie
# Mckenzie Douglas E
# Mckenzie John P
# Mckinney Charles R
# Mcleod Alan
# Mcmichael Elmer L
# Mcmillan Joel L
# Mcmurray David C
# Mcnear
# Mcnulty John S
# Mcpherson John G
# Mcswain
# Md Helicopter
# Md Helicopter Inc
# Md Helicopters
# Md Helicopters Inc
# Mdhi
# Mds Fying Llc
# Mead
# Means Rober C
# Medway
# Melborn Joe B
# Melvin K Callen
# Menzimer Gary Ray
# Mercer
# Merian Richard F
# Merit Aviation Llc
# Merrell Stephen
# Merritt Leslie R
# Merwin
# Meschler Gary R
# Messerschmitt-Boelkow-Blohm
# Messerschmitt-Bolkow-Blohm
# Metcalfe Robert B
# Meuer Mark
# Meyer
# Meyer Clair O
# Meyer Fred J
# Meyer Geoffrey A
# Meyer Robert
# Meyeres F L/Meyeres M M
# Meyers
# Meyers Industries Inc
# Micco Aircraft Company
# Michael A Howard
# Michael A. Watson
# Michael Adamczyk
# Michael Burton
# Michael Cans
# Michael Dean Grissom
# Michael J. Kohout
# Michael Muratore
# Michael R Alexander
# Michael S. Logan
# Michael S/Michael K
# Michael Wilson
# Michaelian
# Michel Paul John
# Mickler Larry J
# Microlites Ptyltd
# Mid-South Custom Craft Inc
# Migas
# Mike Reed
# Mikoyan Gurevich
# Mileski
# Milholland
# Miller
# Miller Charles W
# Miller Gregory S
# Miller Gregory Scott
# Miller J Kirtley
# Miller Raymond A
# Miller Roger
# Miller Steven M
# Miller-Thorp
# Miller/Culpepper
# Millhouse D Scott
# Mills
# Mills Gregory T
# Mills Michael
# Millsap Dennis
# Miltenberger
# Mini Max
# Mini-Max
# Mischanko
# Mischke
# Mitchell David N
# Mitchell Derryle V
# Mitsubishi
# Mkii Corporation
# Mobi-Light
# Moe-Pietenpol
# Moffitt Oscar/ Kit Prostar A/C
# Monnett
# Monnett John T Jr
# Monocoupe
# Monroe Dennis
# Monroig Pedro J
# Montana
# Moody-Siple
# Mooney
# Mooney Aircraft Corp.
# Mooney Airplane Co Inc
# Mooney Airplane Company, Inc.
# Mooney International Corp
# Moore
# Moore Byron J
# Moore David
# Moore Edward R
# Moore Glenn
# Moore Joseph O
# Moore Thomas O
# Morane-Saulnier
# Moravan
# Morehead
# Morgan James E
# Moriarty Marvin
# Mormile Francis W
# Morris George
# Morris Thomas Lee
# Morrisey
# Morrison
# Morrison Joseph
# Morrison Marvin E Jr
# Morrison Rocky V
# Morse Frank L
# Morse, Frank L.
# Moser Georg
# Moses Tim C
# Mosier Robert S
# Mosquito
# Mossman Michael D
# Motley Gary W
# Moulton Howard Wells
# Moyes
# Moyes B/Bailey B
# Moyes Bailey
# Moynahan
# Moynihan Richard D
# Mudge Ray
# Mueller Michael Walter
# Muffett
# Mulec Frank A
# Mulholland Robert A
# Mulloy Charles
# Munson
# Munson Roger J
# Murphy
# Murphy Aircraft
# Murray
# Murray Blair L
# Murray Frank H
# Murray Richard F
# Muse
# Musick
# Mustang
# Mx Aircraft Llc
# Mxr Technologies
# Myers
# Myers Donald E
# Myron Oleson
# N126C Llc
# Nadig Paul K
# Nagel
# Nakajima
# Nalis
# Nanchang
# Nanchang China
# Nappi Tito C
# Nasa Ames Research Center
# Nasdalla
# Naval Aircraft Factory
# Navion
# Nbb Inc
# Nebert
# Needham
# Neefjes
# Neiva
# Neland Richard L
# Nelsen Lynn H
# Nelson
# Nelson Dan H
# Nelson Larry L
# Nelson Miles
# Nelson Steven Paul
# Nelson Sydney
# Nelson Sydney/Nelson Diann
# Nephew Alan H
# New Glasair
# New Kolb Aircraft Co
# New Kolb Aircraft Co Llc
# New Piper
# New Piper Aircraft Inc
# New Standard
# Newbold
# Newcomer
# Newgent, Barry
# Newkirk Thomas Ray
# Newmann Edward W
# Nichols
# Nichols Rans, Inc.
# Nicholson
# Nicholson David F
# Nickel
# Nielsen Martin M
# Niva
# Nokes Matthew
# Nolan
# Noles Vance L
# Nolin
# Noorduyn
# Nord
# Nord (Sncan)
# Nordquist Richard A
# Norman
# Norris
# North American
# North American Rockwell Corp.
# North American-Medore
# North American/Aero Classics
# North American/Schwamm
# North American/Victoria Mnt Lt
# North Wing
# North Wing Design
# North Wing Uum Inc
# North Wing Uum Inc.
# Northland Aviation Llc
# Northrop
# Northwing
# Northwing Design
# Norton Claude C
# Ntbk
# Nunley
# Nuse George
# O'Dell
# Oconnor Paul A
# Oden Weldon Pat
# Offchiss Edward R
# Ogg Richard A
# Ohlgren
# Ohlgren Brent E
# Oliver
# Oliver A Bruce
# Oliver Joseph
# Oliver Lawrence R
# Olmsted Charles A
# Olson
# Olson Kenneth H T
# Olson Perry D
# Omlin Robert G
# Orlican
# Orlican S R O
# Ortiz G/Saint J
# Osborne
# Osprey
# Ostertag Walter G
# Ott
# Otterback
# Otterback Nicholas J
# Ouzts Rodney
# Owen
# Owens
# P Z L -Warszawa-Cnpsl
# P&M Aviation
# P&M Aviation Ltd
# P&M Aviation Ltd.
# Pacific Aerospace Corp Ltd
# Pacific Aerospace Ltd
# Page Joseph E
# Page Russell L
# Pahnke Vernon A
# Palen
# Palmer
# Paquin Michael A
# Paradise Aircraft Usa Llc
# Paradise Usa Llc
# Parker
# Parks J L/Dreffin D
# Parks Jerry R
# Parks Richard A
# Parlette Robert L
# Parsons
# Partenavia
# Partenavia S.P.A.
# Partenavia Spa
# Paul
# Paul B. Johnson
# Paul Gaywood E
# Paul R Seipt
# Pavel
# Pavel Vagner
# Payne Steven R
# Payne/Foster
# Pazmany
# Pdps Pzl-Bielsko
# Pearson
# Pearson Jon M
# Peck
# Peck Norman O
# Pedersen Bjarne Martin
# Peet Charles
# Pegasus
# Pegasus Aviation
# Pekola James W
# Penell Mark A
# Pensinger
# Pepperd Greg J
# Pereira
# Pereyra
# Performer
# Perner/Pitts
# Perth Amboy
# Peryera Arnet
# Peter A Land
# Peter W Stevens
# Peterson Allen L
# Peterson Lancair
# Peterson-Feder-Splinter
# Petrus David Wayne
# Pezetel
# Pf Cub Flyers Llc
# Pflugradt
# Pfouts Alfred L
# Phantom Aeronautics
# Phantom Aircraft Co
# Phelps
# Philip D Anderson
# Phillip B Rolls
# Phillips
# Phillips Ralph W
# Phillips William L
# Phoenix Air
# Piaggio
# Piaggio Aero Industries Spa
# Piasecki/Pike
# Picard Roy J
# Piel
# Pierce, Henry
# Pierson
# Pietenpol
# Piggott John H
# Pik
# Pilatus
# Pilatus Aircraft
# Pilatus Aircraft Ltd
# Pilatus Britten-Norman
# Pilgrim Samuel W Jr
# Pinkston Randy T
# Piontkowski
# Piper
# Piper / Laudeman
# Piper Aerostar
# Piper Aircraft
# Piper Aircraft Corporation
# Piper Aircraft Inc
# Piper Aircraft, Inc.
# Piper Cub Crafters
# Piper-Harris
# Piper/Cub Crafters
# Piper/Wally'S Flyers Inc
# Pipistrel
# Pipistrel D O O
# Pipistrel Doo Ajdovscina
# Pipistrel Italia S R L
# Pitcairn
# Pittman Eddie G
# Pitts
# Pitts Aerobatics
# Pitts Special
# Plante
# Plocher
# Poberezny
# Poe G L/Poe S Y
# Pohoski
# Polaris
# Polaris Motors
# Polit
# Pollack
# Pongracz John M
# Pool
# Poole Robert C Jr
# Porbeck John M
# Porrata Luis G
# Porter Glen
# Porter James Grant
# Porterfield
# Post
# Potez-Air Fouga
# Poulin L/Cullen D
# Powell
# Powerchute
# Powerchute Llc
# Powrachute
# Powrachute Corp
# Powrachute Llc
# Pphu Ekolot
# Preiss Vans
# Prendergast
# Prendergast John/Vans
# Prescot E. Wilkie
# Prichard Kevin
# Pridmore
# Prizio
# Probst
# Progressive Aerodyne
# Progressive Aerodyne Inc
# Pruss Richard S
# Purtee Kevin M
# Pyka Inc
# Pzl
# Pzl Mielec
# Pzl Okecie
# Pzl Warszawa-Okecie
# Pzl-Bielsko
# Pzl-Swidnik
# Qac
# Quad City
# Quad City Aircraft Corp
# Quad City Ultralight
# Quad City Ultralight Acft Corp
# Quad City Ultralight Aircraft
# Quad City Ultralight Corp
# Quad City Ultralights
# Quarnoccio
# Quartz Mountain Aerospace
# Quartz Mountain Aerospace Inc
# Quasar Acft Co Llc
# Quest
# Quest Aircraft Company Llc
# Questair Inc
# Questair, Inc.
# Quickie
# Quicksilver
# Quicksilver Aircraft
# Quicksilver Aircraft Co
# Quicksilver Aircraft Northeast
# Quicksilver Eipper Acft Inc
# Quicksilver Enterprises Inc
# Quicksilver Ii
# Quicksilver Manufacturing Inc
# Quicksilver Mfg
# Quist
# Raddatz Steve
# Radford
# Radford Darrel F
# Radley Vincent
# Raf
# Ragle
# Rainbow Aircraft (Pty) Ltd
# Rainbow Aircraft Pty Ltd
# Rainbow Sky Reach
# Rainbow Sky Reach (Pty) Ltd
# Ralph
# Ralph C Kimball
# Rammel Thomas W
# Rand Robinson
# Randal C Reimer
# Randall Amanda
# Randall Marvin L
# Randall W Grandpre
# Randy Wayne Maloney
# Rans
# Rans Aircraft
# Rans Designs Inc
# Rans Employee Flying Club
# Rans Inc
# Rans S-12
# Rans, Inc.
# Rardin William I
# Ratcliffe John A
# Ratheon Aircraft Company
# Ratte James
# Rauch
# Raudenbush Ernie
# Raven Industries Inc
# Raviraj Mohil
# Ray Aerial Spraying
# Ray Earl D
# Raymon A. King
# Raymond Z Brown
# Raytheon
# Raytheon Aircraft Company
# Raytheon Company
# Raytheon Corporate Jets
# Reamer
# Rearwin
# Redd Tom
# Redding David
# Reed
# Reed Mike
# Reed Roderick
# Reed William A
# Reeves
# Refling
# Rehn
# Reich
# Reilly Charles W
# Reims
# Reims Aviation S.A.
# Reims-Cessna
# Reimus
# Reinboldt Richard A
# Remos
# Remos Acft Gmbh Flugzeugbau
# Remos Aircraft Gmbh
# Remos Aircraft Gmbh Flugzeugba
# Rempe
# Render
# Rennicke Midget Musta
# Replogle
# Republic
# Reupert Mark
# Rewey William M
# Rgj Aviation Llc
# Rhinehart
# Rhoads
# Rhoads, Larry E
# Rice
# Rice Leo B
# Rich
# Rich Harry A
# Richard
# Richard B Carpenter
# Richard Fuist
# Richard Lacourse
# Richard Rank
# Richard S Carpenter
# Richard S Duncan
# Richard Silva
# Richards Heavylift Helo Inc
# Richmond Jim R
# Rick Campbell
# Ridge Lowell H
# Riffel Jerris L
# Riggs Kenneth W
# Risher Jimmy E
# Ristine
# Rittal Alfred Timothy
# Ritter
# Ritter John I
# Rivers Lindsey Lee
# Rivers William J
# Roach Neil
# Robert A Miller
# Robert C. Hanson
# Robert D Carr Jr
# Robert E Bounds
# Robert Fitts
# Robert Frisbey
# Robert Golding
# Robert Hamblin
# Robert J Reimbold
# Robert L Coons
# Robert M. Jones
# Robert Miles
# Robert R. Reiland
# Robert Snyder
# Robert Trembly
# Robert Wood
# Roberto P. Garcia
# Roberts
# Roberts Alan W
# Roberts Bruce W
# Robertson
# Robertson James F
# Robidoux Lionel
# Robinson
# Robinson Helicopter
# Robinson Helicopter Co
# Robinson Helicopter Company
# Robinson Michael E
# Robinson Stewart J
# Rocci Martignoni
# Rockwell
# Rockwell Commander
# Rockwell International
# Roe Cleo
# Roetman Ryland K Jr
# Roger G White
# Roger M Allen
# Rogers
# Rogers George T
# Rogers Homer/Rogers Sheila
# Rogers Kenneth J
# Rolladen Schneider
# Rolladen Schneider Ohg
# Rolladen-Schneider
# Rolladen-Schneider Gmbh
# Rolladen-Schneider Ohg
# Ronald J Bender
# Ronald V White
# Roof
# Root
# Roscher Frederick
# Rose
# Rose Herbert D
# Rose-Rhinehart
# Ross Alfred K/Oneill Terrence
# Ross H/Herriott M
# Ross Jonathan
# Rotary
# Rotherwick
# Rotherwick Hr
# Rotorcraft Developement Corp.
# Rotorcraft Development Corp
# Rotorsport Uk Ltd
# Rotorway
# Rouse
# Rovey Jason H
# Rowe Dennis A
# Rowland
# Royse David
# Rudberg Todd W
# Rudder Dwight K
# Rudolph Ralph Monroe
# Ruiz E
# Rusk
# Russell E Oberg
# Russom Roy G
# Rutan
# Rutten Phil J
# Rutter Herbert G
# Ryan
# Ryan Aeronautical
# Ryan John Steffey
# Ryan W Gross
# Ryskamp Bruce A
# S C Aerostar S .A.
# S C Aerostar S A
# S D Martin
# S M & T Aircraft
# S.C. Aerostar S.A.
# S.N.I.A.S.
# S.O.C.A.T.A.
# S.Z.D.
# Sa300
# Saab
# Saber   Trike
# Saberwing
# Sabre
# Sabrena
# Saccio Thomas A
# Sackman
# Sacrey W Michael
# Sadler
# Sadler Terry
# Sadler Terry A
# Safari
# Salerno Kenneth G Jr
# Sam R Peachey
# Sanders Ben G Iii
# Sanderson
# Sanderson Herbert H
# Sands
# Sands Thomas E
# Sanford
# Santa Fe Aircraft Llc
# Santana
# Santschi Chris A
# Sapp Larry E
# Sasser Allen L
# Sater
# Sauer
# Savage
# Savage Air Llc
# Sawby Scott
# Sc Aerostar Sa
# Sc Iar Sa Brasov
# Scaled Composites
# Schabacker Konrad J
# Schaefer
# Schafer
# Schafer Rick W
# Schaffer
# Schaffer Gary W
# Schauer William A Jr
# Scheel Stanley K
# Scheineman-Van Buren
# Schempp Hirth
# Schempp Hirth Flugzeugbau Gmbh
# Schempp-Hirth
# Schempp-Hirth Flugzeugbau
# Schempp-Hirth Flugzeugbau Gmbh
# Schempp-Hirth K G
# Schendl
# Schleicher
# Schleicher Alexander
# Schleicher Alexander Gmbh & Co
# Schlichtman
# Schmidt Albert D
# Schmidt Donald L
# Schmidt Randall M
# Schmitt
# Schneider
# Schneider John W
# Schneider K/Cook C
# Schneider Richard J
# Schoepflin
# Schooley
# Schoonover John D
# Schosanski John H
# Schrieber Robert L
# Schulke
# Schulman
# Schultz
# Schumacher
# Schupp Edward W
# Schweizer
# Schweizer 300Cbi
# Schweizer Aircraft Corp
# Schweizer(Hughes)Aircraft Corp
# Schweizer, N36289
# Scoda Aeronautical
# Scott
# Scott Mills
# Scott Taylor
# Scott Valdez
# Scottish Aviation
# Scotts-Bell 47 Inc
# Scotts-Bell 47, Inc.
# Sea & Sky Inc
# Sea & Sky Inc Dba Krucker Acft
# Seabourn Scott R
# Seace David A
# Seamax Aircraft
# Seela Gerald L
# Seele
# Segarra Lucas Jr
# Seguin
# Seguine
# Seher
# Seibert Robert M
# Seno Louis C Sr
# Sewell William K
# Seymour
# Seymour Robert M
# Shaffer
# Shaffer Donald
# Shaffer William C
# Shaffstall
# Shanks V Roger
# Shannon Kevin
# Shannon William
# Sharpe William L
# Shaw
# Shaw Douglas Wayne
# Shea
# Sheahen Dane E
# Sheldrick John H
# Shell John
# Shelton Joseph G
# Shepard Jimmy D Jr
# Sherman Craig W
# Shilt Jerry C
# Shiner
# Shirey David A
# Shirley Carl
# Shiver
# Shniderman Ervin Stanley
# Shoemaker James B
# Shook
# Shorey Timothy A
# Short Bros
# Short Bros. & Harland
# Short Brothers Plc
# Shoup Ronald R
# Shpakow Thomas
# Shultz Jeffrey D
# Siai Marchetti
# Siai-Marchetti
# Sibila
# Sibley
# Sidler Mike
# Siebel
# Sieber Paul P
# Siegel Gerald
# Siemens
# Siemer James H
# Sierra
# Sigmon Harvey E
# Sikes
# Sikorsky
# Sikorsky Aircraft Corp
# Sikorsky Aircraft Corporation
# Silence
# Siler Ronald E
# Silfvast
# Silvaire
# Silveira Jonathan A
# Silverlight Aviation
# Silverlight Aviation Llc
# Simmons
# Simmons Gary F
# Simmons Noel
# Simmons William E
# Simpson
# Six Chuter
# Six Chuter Inc
# Six Chuter West Llc
# Six Chuter, Inc
# Six Chutter
# Six-Chuter
# Skaggs Ronnie Lynn
# Skeeter
# Skistmas George
# Skwira Matthew J
# Sky International, Inc.
# Skybolt
# Skykits
# Skykits Corp
# Skykits Corporation
# Skykits Usa Corp
# Skyraider
# Skyrunner
# Skystar
# Skytrails Lsa
# Slaughter Mike
# Slingsby
# Slip Stream
# Slipstream
# Sloan Roger D
# Smiley James E
# Smith
# Smith Albert F
# Smith Allen
# Smith Bret B
# Smith Capella
# Smith Dennis P
# Smith Douglas J.
# Smith Edward I
# Smith Miniplane
# Smith Richard D Jr
# Smith Vilas
# Smith Wylie Jay
# Smithwick/Treidel
# Smysor Kevin
# Smyth
# Smyth Sidewinder
# Smythe Donald F
# Snelling
# Snobird
# Snow
# Snyder Todd W
# Socata
# Softex Invest Llc
# Soko
# Solo Wings
# Somerton David J
# Soneral
# Sonex
# Sonex / John D. Mccarter
# Sonex Aircraft
# Sonex Limited
# Sontonastaso
# Sorensen
# Sorensen Danny
# Sorensen Danny S
# Sorenson
# Sorrell
# Sorrell Aircraft
# Southerland
# Southern Airmotive Corp.
# Southern Powered Parachute
# Southern Powered Parachutes
# Spackman
# Spangenberg
# Spani Wayne M
# Sparks Ralph A
# Sparrow Hawk
# Sparrowhawk
# Spartan
# Spaulding Errol
# Spaur Charles
# Spectrum
# Sperling Richard G
# Spink Robert M
# Sport Flight
# Sport Flight International
# Sport Plane Dynamics Llc
# Sportavia Putzer
# Sportflight International Llc
# Sportine Aviacija
# Sproul
# Sproul Keith A
# Squeglia R/Wheeler W
# Squier
# St Clair
# St Clair David L
# Stafford Wayne H
# Stamper
# Stanley
# Stanley Arthur Freeman
# Stanley B E
# Stanley Ernie Sigurd
# Stanton
# Starduster Ii
# Staudacher Aircraft Inc
# Staudacher Hydroplanes
# Staudacher Jon
# Stearman
# Stearman Aircraft
# Steele
# Steele  John J
# Steele Ralph Bruce
# Steele Samuel D
# Steen
# Steinman Mark E
# Stemme
# Stemme Gmbh & Co
# Stephen F. Graves
# Stephen J Hoffman
# Stephen L Kruer
# Stephens William E
# Stephenson
# Steppling
# Stetson Norman B
# Steven A. Jones
# Steven Bornstein/Thomas Whitta
# Steven G Goonen
# Steven Hardie
# Steven R Mcneese
# Stewart Mw/Stewart Jd
# Stick & Rag Flying Club
# Stiegelmeyer John R
# Still Michael J
# Stinson
# Stirling
# Stits Aircraft
# Stits Flut-R-Bug
# Stoddard Hamilton
# Stoddard-Hamilton
# Stol
# Stol Aircraft Corp
# Stol Llc
# Stolp Starduster
# Stone
# Stone James R
# Storch
# Storch Aviation Australia Pty
# Story Charles Brad
# Stout Garry V
# Stout Gordon
# Stribling
# Stribling James L
# Strong
# Stropki Paul
# Stroup Robert
# Strout Frank
# Stuart
# Stucker Gary
# Stucker Virgil A
# Stucky Steven D
# Stuhlmiller Robert
# Stump
# Stump Bradley
# Stump Great Lakes
# Stutesman Charles Lee
# Sud Aviation
# Sud Aviation/Eurocopter
# Sukhoi
# Suminski Walter M
# Summit
# Sundt Daniel N
# Sungkwon Kim
# Super 18 Llc
# Superior
# Supinski Mark R
# Sutphin
# Sutton
# Sutton William J
# Swalley Mark H
# Swann Lynn J
# Swanson
# Swartz Gene
# Swearingen
# Swearingen T R/Masters W
# Swedener
# Sweeney Timothy J
# Sweet Wayne A
# Swensen
# Swezey T/Molnar D
# Swiezy
# Swift Museum Foundation, Inc.
# Symphony Aircraft Ind Inc
# T Bird
# T Bird Golden Circle Air Inc
# T&T Aviation Inc
# T51 Inc.
# Tacchi Torello F
# Tackabury
# Taft, Malcolm J Sr
# Tail Feather Llc
# Tallent, Chris M.
# Tamarack Helicopters Inc
# Tandem
# Tappen Chris
# Tarantola
# Tarantola Leonard
# Tatelman-Pitts
# Tatkovsky James G
# Taylor
# Taylorcraft
# Taylorcraft Aviation
# Taylorcraft Aviation Corp
# Taylorcraft Aviation Corp.
# Taylorcraft Corp
# Taylorcraft Corporation
# Teal Harry H
# Team
# Team Inc
# Team Rocket
# Team Rocket F-1
# Tecnam
# Ted Smith
# Temco
# Temple Benjamin
# Teratorn
# Terrell Caragol
# Terry F King
# Terry G. Olson
# Terry W. Thayer
# Tetrault Ronad
# Teunis
# Tew William P
# Texas Air Ventures Inc
# Texas Helicopter Corp
# Texas Helicopter Corporation
# Textron Aviation
# Textron Aviation Inc
# Thatcher
# Thibault Michael L
# Thomas
# Thomas A Siminski
# Thomas B Mcgrath
# Thomas C Sikes
# Thomas C. Piper
# Thomas Craig E
# Thomas D. Parkes
# Thomas David W
# Thomas E Hudzinski
# Thomas G Parkhurst
# Thomas J Hankamp
# Thomas J Murray
# Thomas J. Dorsey
# Thomas Lee
# Thomas Long
# Thomas R Wade
# Thomas Scott
# Thomas Stephen
# Thomas Wayne L
# Thomas Wild
# Thompson
# Thompson Bruce D
# Thompson David
# Thompson Howard
# Thompson Tommy W
# Thompson William A
# Thomsen
# Thornton
# Thorp
# Throckmorton Matthew E
# Thrush
# Thrush Aircraft Inc
# Thrush Aircraft Llc
# Thrush Aircraft, Inc.
# Thunder & Colt Airborne Amer
# Thunder Mustang
# Thunderbird Aviation
# Tidd Wesley
# Tifft
# Tiger Aircraft Llc
# Timothy C Williams
# Timothy J Cowper
# Titan
# Titan Aerospace Holdings Inc
# Tl Ultralight
# Tl Ultralight Sro
# Todd Foley
# Toerner Bob
# Toevs
# Toland S/Thornburgh J
# Tolbert Robert R
# Toman Jack Jr
# Tomblingson-Leathers
# Tomei
# Tomlinson Tracy L
# Tompkins
# Tony Dubeansky
# Toomey
# Top Dog
# Topdog Ultralights
# Travel Air
# Treidel Mark/R F D
# Trella
# Triad International Technology
# Trick Trikes
# Trom Wayne
# Tromsness Enterprises Inc
# Troyer
# Trudel
# True Flight Holdings Llc
# Trusty
# Ttx Air Llc
# Tubbs S/Performance
# Tubbs S/Performance Air Inc
# Tuberville
# Tucker Mitchel C
# Tucker Timothy E
# Tucker-Hurni
# Tukan
# Tumbling Goose Llc
# Turck G L/Duflo J T
# Turcotte Jr Robert L
# Turpen
# Tuth
# Tuttle Bruce C
# Twenty Second Street Llc
# Tyler Ives
# U-Fly-It
# Uetz, Walter
# Ulrich Christen
# Ultra Flight Llc
# Ultralight America
# Ultralite Sro
# Ultramagic
# Ultramagic S A
# Ultramagic Sa
# Underland/Grothe/Finstrom
# Univair
# Univair Aircraft Corporation
# Univar
# Universal
# Universal Stinson
# Unknown
# Unregistered
# Upton
# Urban Air Sro
# Urbanczyk Miroslaw
# Us Light Aircraft Corp
# Uskoski
# Valentin
# Valldejuli John A
# Valloric Carl Stephen
# Van B Anthony
# Van Dusen John M
# Van Heeswyk
# Van Hoomissen Gerald J
# Van Kalker John E
# Van'S Aircraft
# Van'S Aircraft, Inc.
# Vandenburg
# Vanderark
# Vanderhoof Steve
# Vanek Jim
# Vans
# Vans Aircraft
# Vans Aircraft Inc
# Varga Aircraft Corp.
# Varner David L
# Vashon Aircraft
# Vaughan Gerald R
# Vaughn
# Veatch
# Veldhuizen
# Velline'S
# Velocity
# Velocity Inc
# Venables Zenith
# Venus
# Versteeg
# Vertical Aviation Technologies
# Vertical Unlimited Llc
# Vicari
# Vickers
# Vickers-Slingsby
# Victor M Cordero
# Viguie G/Viguie M
# Viking (Clarke)
# Viking Air Limited
# Vining John K
# Vink Robert D
# Volaircraft
# Volin
# Vollenweider R/Hurst R F
# Volmer
# Vought
# Vulcanair
# W.H. Hunnicutt
# Waco
# Waco Classic Aircraft
# Waco Classic Aircraft Corp
# Wag Aero
# Wag-Aero
# Waggonner
# Walker
# Walker Edgar E
# Walker J C
# Walker Kenneth
# Walker Louie H
# Walker Phil
# Waller Charles R
# Walling
# Walls Craig C
# Walsh Philip J
# Walter C Smythe
# Walter S Johnson Iii
# Walter Tachiki
# Waltermire
# Walters
# Waltman Theodore J
# Walton Daniel J
# Wampach
# Ward Christopher Barry
# Ware Jerry L
# Warner Aerocraft
# Warner Lewis
# Warth Dennis J
# Wasson Loehle
# Waszak Arthur B
# Waters Peter T
# Watson David E
# Wayland John H
# Wayne D. Teel
# Wayne Miller
# Wayne O Robinson
# Weatherhead Peter L
# Weatherly
# Weatherly Aviation Co Inc
# Weatherly Aviation Company Inc
# Weaver David A
# Weaver Stanley R/Robinson Scot
# Webb
# Weber
# Weddington
# Weinberg
# Weinzierl
# Weiss
# Weiss Denis
# Wejebe Jose
# Welch Floyd L
# Welch Thomas
# Wells John L Jr
# Wells Terry
# Wermling
# Westcott
# Wester/Steiger
# Westerhout/Gagnier
# Western International Avia Inc
# Weston
# Wheat
# Wheeler
# Wheeler C / Wheeler K
# White
# Whitehead
# Whittman
# Whittridge Richard D
# Wicks Air Center Llc
# Wielt
# Wiggins
# Wight
# Wight Albert A
# Wilde Daniel L
# Wilderoder
# Wildman
# Wiley
# Wiley C W
# Wilhelm
# Wilkinson Lorin L
# Willerton
# Willey
# William D Durkee
# William D Telfair/Zia Z Telfai
# William E. Furr
# William L Bell
# William M Oprendek
# William P. Crowell
# William Wright
# Williams Christopher T
# Williams Glenn
# Williams Helicopter Corp
# Williams John
# Williams Myron G
# Williams Yakovlev
# Willie Bennett
# Willoughby Pete A
# Wilson
# Wilson Michael A
# Wilson William M
# Wim J Huisman
# Winder Robert S
# Wing
# Wing Harold
# Wing John R
# Wingren Norman
# Wings An Things Inc
# Wingtip To Wingtip Llc
# Wingtip To Wingtip, Llc
# Winship Kent S
# Winston W Walker
# Wittman
# Wittman D R/Wittman D M
# Wogenstahl Wallace L
# Wohaska John
# Wohnoutka Steven M
# Wolfe
# Wolseley Motors, Inc.
# Wonder Michael S
# Wood
# Woodrow Larry W
# Woods
# Woods Rufus Iii
# Woodward Harold L
# Woolston Glenn E
# Wooters
# Wootton, John
# Worgull
# World Aircraft Co
# Worley Dennis
# Worthington
# Worthington Donald Wayne
# Wragg George
# Wrb Associates, Llc.
# Wren Ronnie D
# Wright
# Wright B Flyer Inc
# Wright Bruce M
# Wright Daniel J
# Wsk Pzl Mielec
# Wsk-Mielec
# Wsk-Pzl Meilec
# Wsk-Pzl Warzawa-Okecie
# Wsl Pzl
# X-Air Llc
# Xtremeair Gmbh
# Yakovlev
# Yakovlev/Day
# Yamokoski William
# Yates
# Yates Mike E
# Yates W/Lazar M
# Yeager Inc.
# York Ronald J
# Yost Edwin S
# Young Dee C
# Young John E
# Young Robert Herman
# Youngs William D
# Younkin J R
# Yowell
# Yuneec
# Z-Hi-Max
# Zach Vans
# Zeiler
# Zenair
# Zenair Ltd
# Zenair Zodiac
# Zenith
# Zenith Acft Co
# Zenith Aircraft Co
# Zidek
# Ziermann
# Zimmerman
# Zivko Aeronautics Inc
# Zlin
# Zlin Aviation
# Zs Delta-Bielsko Wroclaw
# Zubair S Khan
# Zwicker Murray R
#
# Top 20 makes by frequency:
# Make
# Cessna                         5177
# Piper                          3066
# Beech                          1098
# Bell                            490
# Mooney                          274
# Robinson Helicopter             219
# Air Tractor Inc                 211
# Robinson                        211
# Cirrus Design Corp              198
# Boeing                          190
# Bellanca                        173
# Robinson Helicopter Company     168
# Aeronca                         163
# Maule                           161
# Schweizer                       160
# Hughes                          134
# Air Tractor                     128
# Champion                        126
# Luscombe                        113
# Eurocopter                      111
# Name: count, dtype: int64
#
# Potential inconsistencies (different versions of the same make):
# C:\Users\HP\AppData\Local\Temp\ipykernel_12292\49976367.py:5: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/cleaned_aviation_data_1.csv')  # Replace with your actual file path if different

# %%
# Create a standardization mapping for the most common manufacturers
make_mapping = {
    # Cessna variations
    'Cessna Aircraft': 'Cessna',
    'Cessna Aircraft Co': 'Cessna',
    'Cessna Aircraft Co.': 'Cessna',
    
    # Piper variations
    'Piper Aircraft': 'Piper',
    'Piper Aircraft Corporation': 'Piper',
    'Piper Aircraft Inc': 'Piper',
    'Piper Aircraft, Inc.': 'Piper',
    
    # Beech variations
    'Beech Aircraft Corp': 'Beech',
    'Beech Aircraft Corporation': 'Beech',
    'Beechcraft': 'Beech',
    'Beechcraft Corporation': 'Beech',
    
    # Bell variations
    'Bell Helicopter': 'Bell',
    'Bell Helicopter Textron': 'Bell',
    
    # Robinson variations
    'Robinson Helicopter': 'Robinson',
    'Robinson Helicopter Co': 'Robinson',
    'Robinson Helicopter Company': 'Robinson',
    
    # Air Tractor variations
    'Air Tractor': 'Air Tractor',
    'Air Tractor Inc': 'Air Tractor',
    'Air Tractor Inc.': 'Air Tractor',
    'Air Tractor, Inc.': 'Air Tractor',
    
    # Cirrus variations
    'Cirrus': 'Cirrus',
    'Cirrus Design': 'Cirrus',
    'Cirrus Design Corp': 'Cirrus',
    'Cirrus Design Corp.': 'Cirrus',
    'Cirrus Design Corporation': 'Cirrus',
    
    # Boeing variations
    'Boeing Company': 'Boeing',
    'Boeing-Stearman': 'Boeing',
    
    # Other common manufacturers
    'Aeronca Aircraft Corporation': 'Aeronca',
    'Bellanca': 'Bellanca',
    'Maule': 'Maule',
    'Schweizer': 'Schweizer',
    'Schweizer Aircraft Corp': 'Schweizer',
    'Hughes Helicopters Inc': 'Hughes',
    'Champion': 'Champion',
    'Luscombe': 'Luscombe',
    'Eurocopter': 'Eurocopter'
}

# Apply the standardization mapping
df['Make_Standardized'] = df['Make'].replace(make_mapping)

# Check results for the top makes to see if standardization worked
print("Top makes after standardization:")
print(df['Make_Standardized'].value_counts().head(20))

# Compare original vs standardized counts
print("\nComparison of top manufacturers before and after standardization:")
original_top = df['Make'].value_counts().head(10)
standardized_top = df['Make_Standardized'].value_counts().head(10)

comparison = pd.DataFrame({
    'Original Count': original_top,
    'Standardized Count': standardized_top.reindex(original_top.index).fillna(0).astype(int)
})
print(comparison)
# Out:
# Top makes after standardization:
# Make_Standardized
# Cessna         5206
# Piper          3098
# Beech          1113
# Robinson        614
# Bell            513
# Air Tractor     345
# Cirrus          308
# Mooney          274
# Boeing          192
# Schweizer       179
# Bellanca        173
# Aeronca         164
# Maule           161
# Hughes          137
# Champion        126
# Luscombe        113
# Eurocopter      111
# Stinson         108
# Vans            107
# Grumman          97
# Name: count, dtype: int64
#
# Comparison of top manufacturers before and after standardization:
#                      Original Count  Standardized Count
# Make
# Cessna                         5177                5206
# Piper                          3066                3098
# Beech                          1098                1113
# Bell                            490                 513
# Mooney                          274                 274
# Robinson Helicopter             219                   0
# Air Tractor Inc                 211                   0
# Robinson                        211                 614
# Cirrus Design Corp              198                   0
# Boeing                          190                 192

# %%
# Check Model column values and their frequencies
model_counts = df['Model'].value_counts()

print(f"Number of unique values in Model column: {len(df['Model'].unique())}")
print("\nTop 30 most common Model values:")
print(model_counts.head(30))

# Look for potential model standardization issues
# First, convert to lowercase for comparison
df['Model_lower'] = df['Model'].str.lower() if df['Model'].dtype == 'object' else df['Model']

# Find models that might be the same but with different formatting
model_lower_counts = df['Model_lower'].value_counts()
potential_duplicates = []

# Check common models for variations
common_models = ['172', 'pa28', '182', 'sr22', 'r44']
for model in common_models:
    similar_models = [m for m in model_lower_counts.index if model in str(m).lower()]
    if len(similar_models) > 1:
        print(f"\nPotential variations of model {model}:")
        for similar in similar_models:
            count = model_lower_counts[similar]
            print(f"  {similar}: {count}")

# Check for models with numbers and letters that might need standardization
# For example, "172" vs "C-172" vs "Cessna 172"
print("\nSample of models that might need standardization:")
for make in ["Cessna", "Piper", "Beech"]:
    # Get standardized make
    std_make = make
    if make in make_mapping:
        std_make = make_mapping[make]
    
    # Filter dataset for this make
    make_data = df[df['Make_Standardized'] == std_make]
    
    print(f"\n{make} models:")
    print(make_data['Model'].value_counts().head(10))
# Out:
# Number of unique values in Model column: 4782
#
# Top 30 most common Model values:
# Model
# 172          614
# PA28         229
# 182          225
# 152          211
# SR22         204
# 172S         183
# R44          180
# 180          177
# 172N         165
# A36          163
# R44 II       148
# PA-18-150    143
# 172M         141
# 150          127
# PA-28-140    117
# R22 BETA     114
# 206          106
# 140           96
# 172P          96
# R22           93
# 206B          91
# PA18          84
# 170B          81
# 7AC           79
# M20J          77
# 7GCBC         76
# A185F         76
# PA-28-180     74
# PA-28-161     73
# 269C          72
# Name: count, dtype: int64
#
# Potential variations of model 172:
#   172: 614
#   172s: 183
#   172n: 165
#   172m: 141
#   172p: 96
#   172r: 71
#   172rg: 44
#   172k: 38
#   172h: 28
#   172f: 23
#   r172k: 22
#   172l: 19
#   172d: 14
#   172g: 14
#   172e: 13
#   172b: 12
#   172i: 11
#   172a: 11
#   r172: 8
#   r172e: 6
#   172sp: 6
#   172c: 6
#   172 - r: 3
#   172 - n: 2
#   172 - s: 2
#   p172d: 2
#   172 - h: 1
#   172q: 1
#   cessna fr172: 1
#   ce-172m: 1
#   172 sp: 1
#   172 n: 1
#   172 m: 1
#   c-172rg: 1
#   172 rg: 1
#   172 - f: 1
#   172 - m: 1
#   172xp: 1
#
# Potential variations of model pa28:
#   pa28: 229
#   pa28r: 53
#   pa28-151: 5
#   pa28 151: 3
#   pa28rt: 2
#   pa28-140: 2
#   pa28 - 140: 1
#   pa28 - 180: 1
#   pa28-200: 1
#   pa28-180: 1
#   pa28-236: 1
#   pa28 - 160: 1
#   pa28 - 161: 1
#   pa28 - 181: 1
#   pa28r - 201t: 1
#   pa28-150: 1
#
# Potential variations of model 182:
#   182: 225
#   182p: 59
#   182q: 48
#   r182: 37
#   182a: 35
#   tr182: 30
#   182t: 29
#   t182t: 28
#   182d: 18
#   182j: 17
#   182c: 17
#   182k: 15
#   182m: 15
#   182s: 14
#   182h: 14
#   182r: 13
#   182l: 13
#   182g: 13
#   182f: 12
#   182e: 11
#   182b: 9
#   t182: 8
#   182n: 7
#   c-182: 2
#   r182rg: 1
#
# Potential variations of model sr22:
#   sr22: 204
#   sr22t: 18
#   sr22 - no series: 2
#
# Potential variations of model r44:
#   r44: 180
#   r44 ii: 148
#   r44 - ii: 5
#   r44 clipper 1: 1
#
# Sample of models that might need standardization:
#
# Cessna models:
# Model
# 172     612
# 182     225
# 152     211
# 172S    183
# 180     177
# 172N    165
# 172M    141
# 150     127
# 140      96
# 172P     96
# Name: count, dtype: int64
#
# Piper models:
# Model
# PA28         229
# PA-18-150    137
# PA-28-140    117
# PA18          83
# PA-28-180     74
# PA-28-161     73
# PA-28-181     60
# PA 18-150     57
# PA32          55
# PA-12         54
# Name: count, dtype: int64
#
# Beech models:
# Model
# A36      140
# 58        58
# 35        41
# C23       39
# V35B      29
# V35       29
# F33A      26
# 36        26
# 76        23
# A36TC     23
# Name: count, dtype: int64

# %%
# Create model family standardization
def standardize_model_family(model):
    model_str = str(model).upper().strip()
    
    # Cessna families
    if '172' in model_str:
        return 'Cessna 172 Family'
    elif '182' in model_str:
        return 'Cessna 182 Family'
    elif '152' in model_str:
        return 'Cessna 152 Family'
    elif '150' in model_str:
        return 'Cessna 150 Family'
    elif '180' in model_str and not 'PA' in model_str:  # Avoid matching PA-28-180
        return 'Cessna 180 Family'
    
    # Piper families
    elif any(x in model_str for x in ['PA28', 'PA-28']):
        return 'Piper PA-28 Family'
    elif any(x in model_str for x in ['PA18', 'PA-18']):
        return 'Piper PA-18 Family'
    elif any(x in model_str for x in ['PA32', 'PA-32']):
        return 'Piper PA-32 Family'
    
    # Robinson helicopters
    elif model_str.startswith('R44'):
        return 'Robinson R44 Family'
    elif model_str.startswith('R22'):
        return 'Robinson R22 Family'
    
    # Beechcraft families
    elif 'A36' in model_str:
        return 'Beech A36 Family'
    elif model_str == '58' or model_str.startswith('58 '):
        return 'Beech 58 Family'
    
    # If no match, return the original
    return model

# Create a more specific model standardization for variants
def standardize_model_variant(model, make):
    if not isinstance(model, str) or not isinstance(make, str):
        return model
    
    model_str = model.upper().strip()
    make_std = make.upper().strip()
    
    # Standardize Cessna 172 variants
    if '172' in model_str and 'CESS' in make_std:
        # Remove any "CESSNA" or "C-" prefix
        clean_model = model_str.replace('CESSNA ', '').replace('CE-', '').replace('C-', '')
        
        # Extract the base model and variant
        if 'RG' in clean_model:
            return '172RG'  # Retractable Gear version
        elif clean_model.startswith('172') and len(clean_model) > 3:
            base = '172'
            variant = clean_model.replace('172', '').strip('-. ')
            if variant:
                return f'172{variant[0]}'  # Take just the first character of the variant
            else:
                return '172'
        else:
            return '172'
    
    # Standardize Piper PA-28 variants
    elif any(x in model_str for x in ['PA28', 'PA-28']) and 'PIPER' in make_std:
        if 'ARROW' in model_str or 'R' in model_str:
            return 'PA-28R'  # Arrow models
        elif '161' in model_str:
            return 'PA-28-161'  # Warrior II
        elif '181' in model_str:
            return 'PA-28-181'  # Archer II/III
        elif '140' in model_str:
            return 'PA-28-140'  # Cruiser/Cherokee 140
        elif '180' in model_str:
            return 'PA-28-180'  # Cherokee 180
        else:
            return 'PA-28'
    
    # If no specific standardization, return the original
    return model

# Apply the standardization
df['Model_Family'] = df['Model'].apply(standardize_model_family)
df['Model_Standardized'] = df.apply(lambda x: standardize_model_variant(x['Model'], x['Make_Standardized']), axis=1)

# Check the results
print("Top Model Families:")
print(df['Model_Family'].value_counts().head(10))

print("\nTop Standardized Model Variants:")
print(df['Model_Standardized'].value_counts().head(10))
# Out:
# Top Model Families:
# Model_Family
# Cessna 172 Family      1566
# Piper PA-28 Family      818
# Cessna 150 Family       701
# Cessna 182 Family       690
# Cessna 180 Family       340
# Robinson R44 Family     334
# Piper PA-32 Family      284
# Robinson R22 Family     240
# Cessna 152 Family       218
# SR22                    204
# Name: count, dtype: int64
#
# Top Standardized Model Variants:
# Model_Standardized
# 172      652
# PA-28    335
# 182      225
# 152      211
# SR22     204
# 172S     192
# R44      180
# 180      177
# 172N     168
# A36      163
# Name: count, dtype: int64

# %%
# Check Aircraft.Category values and frequencies
category_counts = df['Aircraft.Category'].value_counts()

print(f"Number of unique values in Aircraft.Category column: {len(df['Aircraft.Category'].unique())}")
print("\nAll Aircraft.Category values with counts:")
print(category_counts)

# Check for potential standardization issues by converting to lowercase
df['Category_lower'] = df['Aircraft.Category'].str.lower() if df['Aircraft.Category'].dtype == 'object' else df['Aircraft.Category']
category_lower_counts = df['Category_lower'].value_counts()

# Check for similar categories that might need standardization
print("\nPotential category standardization issues:")
similar_categories = {}
for category in category_lower_counts.index:
    if not isinstance(category, str):
        continue
    # Look for similar categories
    for other_category in category_lower_counts.index:
        if not isinstance(other_category, str):
            continue
        if category != other_category and (category in other_category or other_category in category):
            if category not in similar_categories:
                similar_categories[category] = []
            if other_category not in similar_categories[category]:
                similar_categories[category].append(other_category)

# Print potential similar categories
for category, similar in similar_categories.items():
    if similar:
        print(f"Category '{category}' might be similar to: {', '.join(similar)}")
        print(f"  '{category}' count: {category_lower_counts[category]}")
        for s in similar:
            print(f"  '{s}' count: {category_lower_counts[s]}")
        print()

# Create a standardization mapping for Aircraft.Category
category_mapping = {
    # Add your mappings here based on the analysis
}

# Apply the standardization
if category_mapping:
    df['Aircraft.Category_Standardized'] = df['Aircraft.Category'].replace(category_mapping)
    
    # Check the results
    print("Standardized Aircraft.Category values with counts:")
    print(df['Aircraft.Category_Standardized'].value_counts())
# Out:
# Number of unique values in Aircraft.Category column: 13
#
# All Aircraft.Category values with counts:
# Aircraft.Category
# Airplane             17420
# Helicopter            2070
# Glider                 349
# Weight-Shift           158
# Gyrocraft              136
# Balloon                 87
# Powered Parachute       87
# Ultralight              18
# WSFT                     7
# Unknown                  4
# Rocket                   1
# Blimp                    1
# ULTR                     1
# Name: count, dtype: int64
#
# Potential category standardization issues:
# Category 'ultralight' might be similar to: ultr
#   'ultralight' count: 18
#   'ultr' count: 1
#
# Category 'ultr' might be similar to: ultralight
#   'ultr' count: 1
#   'ultralight' count: 18

# %%
# Create standardization mapping for Aircraft.Category
category_mapping = {
    # Handle abbreviations
    'ULTR': 'Ultralight',
    'WSFT': 'Weight-Shift',
    
    # Ensure consistent capitalization if needed
    'Unknown': 'Unknown'  # This is a placeholder example
}

# Apply the standardization
df['Aircraft.Category_Standardized'] = df['Aircraft.Category'].replace(category_mapping)

# Check the results
print("Standardized Aircraft.Category values with counts:")
print(df['Aircraft.Category_Standardized'].value_counts())

# Check how the standardization affected counts
print("\nComparison of Aircraft Categories before and after standardization:")
original_category_counts = df['Aircraft.Category'].value_counts()
standard_category_counts = df['Aircraft.Category_Standardized'].value_counts()

# Create a comparison dataframe for categories that changed
category_comparison = pd.DataFrame({
    'Original Count': original_category_counts,
    'Standardized Count': standard_category_counts.reindex(original_category_counts.index).fillna(0).astype(int)
})
print(category_comparison)
# Out:
# Standardized Aircraft.Category values with counts:
# Aircraft.Category_Standardized
# Airplane             17420
# Helicopter            2070
# Glider                 349
# Weight-Shift           165
# Gyrocraft              136
# Balloon                 87
# Powered Parachute       87
# Ultralight              19
# Unknown                  4
# Rocket                   1
# Blimp                    1
# Name: count, dtype: int64
#
# Comparison of Aircraft Categories before and after standardization:
#                    Original Count  Standardized Count
# Aircraft.Category
# Airplane                    17420               17420
# Helicopter                   2070                2070
# Glider                        349                 349
# Weight-Shift                  158                 165
# Gyrocraft                     136                 136
# Balloon                        87                  87
# Powered Parachute              87                  87
# Ultralight                     18                  19
# WSFT                            7                   0
# Unknown                         4                   4
# Rocket                          1                   1
# Blimp                           1                   1
# ULTR                            1                   0

# %%
# Check Engine.Type values and frequencies
engine_counts = df['Engine.Type'].value_counts()

print(f"Number of unique values in Engine.Type column: {len(df['Engine.Type'].unique())}")
print("\nAll Engine.Type values with counts:")
print(engine_counts)

# Check for potential standardization issues by converting to lowercase
df['Engine_lower'] = df['Engine.Type'].str.lower() if df['Engine.Type'].dtype == 'object' else df['Engine.Type']
engine_lower_counts = df['Engine_lower'].value_counts()

# Check for similar engine types that might need standardization
print("\nPotential engine type standardization issues:")
similar_engines = {}
for engine in engine_lower_counts.index:
    if not isinstance(engine, str):
        continue
    # Look for similar engine types
    for other_engine in engine_lower_counts.index:
        if not isinstance(other_engine, str):
            continue
        if engine != other_engine and (engine in other_engine or other_engine in engine):
            if engine not in similar_engines:
                similar_engines[engine] = []
            if other_engine not in similar_engines[engine]:
                similar_engines[engine].append(other_engine)

# Print potential similar engine types
for engine, similar in similar_engines.items():
    if similar:
        print(f"Engine type '{engine}' might be similar to: {', '.join(similar)}")
        print(f"  '{engine}' count: {engine_lower_counts[engine]}")
        for s in similar:
            print(f"  '{s}' count: {engine_lower_counts[s]}")
        print()

# Create a standardization mapping for Engine.Type
engine_mapping = {
    # You'll define mappings here based on the analysis results
}

# Apply the standardization if you've defined mappings
if engine_mapping:
    df['Engine.Type_Standardized'] = df['Engine.Type'].replace(engine_mapping)
    
    # Check the results
    print("Standardized Engine.Type values with counts:")
    print(df['Engine.Type_Standardized'].value_counts())
# Out:
# Number of unique values in Engine.Type column: 13
#
# All Engine.Type values with counts:
# Engine.Type
# Reciprocating      15735
# Turbo Prop           990
# Turbo Shaft          915
# Turbo Fan            365
# Turbo Jet             90
# Unknown               16
# Electric               8
# NONE                   2
# Hybrid Rocket          1
# Geared Turbofan        1
# LR                     1
# UNK                    1
# Name: count, dtype: int64
#
# Potential engine type standardization issues:
# Engine type 'unknown' might be similar to: unk
#   'unknown' count: 16
#   'unk' count: 1
#
# Engine type 'unk' might be similar to: unknown
#   'unk' count: 1
#   'unknown' count: 16

# %%
# Create standardization mapping for Engine.Type
engine_mapping = {
    # Handle unknown values
    'UNK': 'Unknown',
    
    # Standardize turbine engine terminology
    'Turbo Prop': 'Turboprop',
    'Turbo Shaft': 'Turboshaft',
    'Turbo Fan': 'Turbofan',
    'Turbo Jet': 'Turbojet',
    'Geared Turbofan': 'Turbofan',
    
    # Standardize other uncommon types
    'NONE': 'None',
    'LR': 'Unknown'  # Unless you know what LR specifically refers to
}

# Apply the standardization
df['Engine.Type_Standardized'] = df['Engine.Type'].replace(engine_mapping)

# Check the results
print("Standardized Engine.Type values with counts:")
print(df['Engine.Type_Standardized'].value_counts())

# Check how the standardization affected counts
print("\nComparison of Engine Types before and after standardization:")
original_counts = df['Engine.Type'].value_counts()
standard_counts = df['Engine.Type_Standardized'].value_counts()

# Create a comparison dataframe
engine_comparison = pd.DataFrame({
    'Original Count': original_counts,
    'Standardized Count': standard_counts.reindex(original_counts.index).fillna(0).astype(int)
})
print(engine_comparison)
# Out:
# Standardized Engine.Type values with counts:
# Engine.Type_Standardized
# Reciprocating    15735
# Turboprop          990
# Turboshaft         915
# Turbofan           366
# Turbojet            90
# Unknown             18
# Electric             8
# None                 2
# Hybrid Rocket        1
# Name: count, dtype: int64
#
# Comparison of Engine Types before and after standardization:
#                  Original Count  Standardized Count
# Engine.Type
# Reciprocating             15735               15735
# Turbo Prop                  990                   0
# Turbo Shaft                 915                   0
# Turbo Fan                   365                   0
# Turbo Jet                    90                   0
# Unknown                      16                  18
# Electric                      8                   8
# NONE                          2                   0
# Hybrid Rocket                 1                   1
# Geared Turbofan               1                   0
# LR                            1                   0
# UNK                           1                   0

# %%
# Check Aircraft.damage values and frequencies
damage_counts = df['Aircraft.damage'].value_counts()

print(f"Number of unique values in Aircraft.damage column: {len(df['Aircraft.damage'].unique())}")
print("\nAll Aircraft.damage values with counts:")
print(damage_counts)

# Check for potential standardization issues by converting to lowercase
df['Damage_lower'] = df['Aircraft.damage'].str.lower() if df['Aircraft.damage'].dtype == 'object' else df['Aircraft.damage']
damage_lower_counts = df['Damage_lower'].value_counts()

# Check for similar damage categories that might need standardization
print("\nPotential damage category standardization issues:")
similar_damages = {}
for damage in damage_lower_counts.index:
    if not isinstance(damage, str):
        continue
    # Look for similar damage categories
    for other_damage in damage_lower_counts.index:
        if not isinstance(other_damage, str):
            continue
        if damage != other_damage and (damage in other_damage or other_damage in damage):
            if damage not in similar_damages:
                similar_damages[damage] = []
            if other_damage not in similar_damages[damage]:
                similar_damages[damage].append(other_damage)

# Print potential similar damage categories
for damage, similar in similar_damages.items():
    if similar:
        print(f"Damage category '{damage}' might be similar to: {', '.join(similar)}")
        print(f"  '{damage}' count: {damage_lower_counts[damage]}")
        for s in similar:
            print(f"  '{s}' count: {damage_lower_counts[s]}")
        print()
# Out:
# Number of unique values in Aircraft.damage column: 4
#
# All Aircraft.damage values with counts:
# Aircraft.damage
# Substantial    17965
# Destroyed       1917
# Minor            417
# Unknown           40
# Name: count, dtype: int64
#
# Potential damage category standardization issues:

# %%
# Check Weather.Condition values and frequencies
weather_counts = df['Weather.Condition'].value_counts()

print(f"Number of unique values in Weather.Condition column: {len(df['Weather.Condition'].unique())}")
print("\nAll Weather.Condition values with counts:")
print(weather_counts)

# Check for potential standardization issues by converting to lowercase
df['Weather_lower'] = df['Weather.Condition'].str.lower() if df['Weather.Condition'].dtype == 'object' else df['Weather.Condition']
weather_lower_counts = df['Weather_lower'].value_counts()

# Check for similar weather conditions that might need standardization
print("\nPotential weather condition standardization issues:")
similar_conditions = {}
for condition in weather_lower_counts.index:
    if not isinstance(condition, str):
        continue
    # Look for similar weather conditions
    for other_condition in weather_lower_counts.index:
        if not isinstance(other_condition, str):
            continue
        if condition != other_condition and (condition in other_condition or other_condition in condition):
            if condition not in similar_conditions:
                similar_conditions[condition] = []
            if other_condition not in similar_conditions[condition]:
                similar_conditions[condition].append(other_condition)

# Print potential similar weather conditions
for condition, similar in similar_conditions.items():
    if similar:
        print(f"Weather condition '{condition}' might be similar to: {', '.join(similar)}")
        print(f"  '{condition}' count: {weather_lower_counts[condition]}")
        for s in similar:
            print(f"  '{s}' count: {weather_lower_counts[s]}")
        print()
# Out:
# Number of unique values in Weather.Condition column: 3
#
# All Weather.Condition values with counts:
# Weather.Condition
# VMC    19232
# IMC      944
# Unk      163
# Name: count, dtype: int64
#
# Potential weather condition standardization issues:

# %%
# Check Broad.phase.of.flight values and frequencies
flight_phase_counts = df['Broad.phase.of.flight'].value_counts()

print(f"Number of unique values in Broad.phase.of.flight column: {len(df['Broad.phase.of.flight'].unique())}")
print("\nAll Broad.phase.of.flight values with counts:")
print(flight_phase_counts)

# Check for potential standardization issues by converting to lowercase
df['Flight_phase_lower'] = df['Broad.phase.of.flight'].str.lower() if df['Broad.phase.of.flight'].dtype == 'object' else df['Broad.phase.of.flight']
flight_phase_lower_counts = df['Flight_phase_lower'].value_counts()

# Check for similar flight phases that might need standardization
print("\nPotential flight phase standardization issues:")
similar_phases = {}
for phase in flight_phase_lower_counts.index:
    if not isinstance(phase, str):
        continue
    # Look for similar flight phases
    for other_phase in flight_phase_lower_counts.index:
        if not isinstance(other_phase, str):
            continue
        if phase != other_phase and (phase in other_phase or other_phase in phase):
            if phase not in similar_phases:
                similar_phases[phase] = []
            if other_phase not in similar_phases[phase]:
                similar_phases[phase].append(other_phase)

# Print potential similar flight phases
for phase, similar in similar_phases.items():
    if similar:
        print(f"Flight phase '{phase}' might be similar to: {', '.join(similar)}")
        print(f"  '{phase}' count: {flight_phase_lower_counts[phase]}")
        for s in similar:
            print(f"  '{s}' count: {flight_phase_lower_counts[s]}")
        print()
# Out:
# Number of unique values in Broad.phase.of.flight column: 6
#
# All Broad.phase.of.flight values with counts:
# Broad.phase.of.flight
# Landing    30
# Takeoff    25
# Cruise     23
# Other      13
# Unknown     4
# Name: count, dtype: int64
#
# Potential flight phase standardization issues:

# %%
# Save to CSV
yearly_safety.to_csv('yearly_safety_summary.csv', index=False)
